# %% [markdown]
# BL
# 1. epoch motor planning - ?? timing
# 2. epoch motor execution - ?? timing

# %%
import mne
import os
from utils import check_paths
import numpy as np
import pandas as pd
import pickle

import matplotlib.pyplot as plt
# %matplotlib qt

# %% [markdown]
# # PLANNING / EXECUTION

# %% [markdown]
# **GROUP**

# %% [markdown]
# Epoching

# %% [markdown]
# ?? save metadata and planning events ??

# %%
# Create planning / execution epochs for subjects
eeg_data_dir = 'D:\\BonoKat\\research project\\# study 1\\eeg_data\\set'
group = 'Y'
task = '_BL' # ['_BL', '_MAIN']
task_stage = '_go' # '_plan' for PLANNING or '_go' for EXECUTION

subs_dir = os.path.join(eeg_data_dir, group)
figs_dir = os.path.join(eeg_data_dir, 'figures', group, 'epochs', task)
check_paths(os.path.join(eeg_data_dir, 'figures', group))
check_paths(os.path.join(eeg_data_dir, 'figures', group, 'epochs'))
check_paths(figs_dir)

# trial infor dictionary
trial_num_data = {'sub': [], 'task_stage': [], 'trial_num': []}

# metadata for each epoch shall include events from the range: [-0.5, 0.7] s,
# i.e. starting with stimulus onset and expanding beyond the end of the epoch
if task_stage == '_plan':
    metadata_tmin, metadata_tmax = -0.5, 1 # [-0.5, 0.7] for _go or [-0.5, 0.5] for _plan
    # events of interest
    row_events = ['prepare'] # ['prepare']
    # timing of the epochs
    epochs_tmin, epochs_tmax = -0.5, 0.5  # epochs range: [-0.5, 0.7] for _go or [-0.5, 0.5] for _plan

else:
    metadata_tmin, metadata_tmax = -0.5, 0.5 # [-0.5, 0.7] for _go or [-0.5, 0.5] for _plan
    # events of interest
    row_events = ['key_press'] # ['go']
    # timing of the epochs
    epochs_tmin, epochs_tmax = -0.5, 0.5  # epochs range: [-0.5, 0.7] for _go or [-0.5, 0.5] for _plan

baseline_epo = (epochs_tmin, epochs_tmax) # baseline is the average of the epoch


for sub_name in os.listdir(subs_dir): # os.listdir(subs_dir) OR ['s1_pac_sub00'] # EXCLUDED sub19 - no baseline trigger

    print(f'Creating epochs for {task} task in {sub_name}...')

    preproc_dir = os.path.join(subs_dir, sub_name, 'preproc')
    filt_dir = os.path.join(subs_dir, sub_name, 'preproc', 'filt')
    analysis_dir = os.path.join(preproc_dir, 'analysis')

    eeg_data_path = os.path.join(analysis_dir, f'{sub_name}{task}_reconst.fif')
    raw = mne.io.read_raw_fif(eeg_data_path, preload=True)
    sf = raw.info['sfreq'] # sampling frequency of data

    # Open events from pickle file
    with open(os.path.join(filt_dir, f'{sub_name}{task}_events.pkl'), 'rb') as pickle_file:
        events = pickle.load(pickle_file)

    # check if event time samples are unique
    for i in range(len(events[0]) - 1):
        if events[0][i, 0] == events[0][i+1, 0]:
            print(f'Time sample for events {events[0][i, 2]} and {events[0][i+1, 2]} in trials {i}-{i+1} are not unique!')
            events[0][i+1, 0] = events[0][i, 0] + 1

   # auto-create metadata:
    # this also returns a new events array and an event_id dictionary. we'll see
    # later why this is important
    metadata, events, event_id = mne.epochs.make_metadata(
        events=events[0],
        event_id=events[1],
        tmin=metadata_tmin,
        tmax=metadata_tmax,
        sfreq=raw.info["sfreq"],
        row_events=row_events
    )

    epochs = mne.Epochs(
        raw=raw,
        tmin=epochs_tmin,
        tmax=epochs_tmax,
        events=events,
        event_id=event_id,
        baseline=baseline_epo,
        metadata=metadata,
        reject_by_annotation=True,
        preload=True,
    )

    if task_stage == '_plan':
        epochs = epochs["go.isna() & isi2.isna() & key_press.isna()"]
    
    else:
        epochs = epochs["prepare.isna() & new_trial.isna()"]

    print(f'TOTAL NUMBER OF EPOCHS: {len(epochs)}')

    # Append data to the dictionary
    trial_num_data['sub'].append(sub_name)
    trial_num_data['task_stage'].append(task_stage)
    trial_num_data['trial_num'].append(len(epochs))


    # Save the epochs
    epochs.save(os.path.join(analysis_dir, f"{sub_name}{task}_epochs{task_stage}-epo.fif"), overwrite=True)
    print(f'Epochs for {task}{task_stage} in {sub_name} saved SUCCESSFULLY')

    # Plot ERP
    fig_erp = epochs.average().plot(gfp=True, spatial_colors=True)
    # Save the ERP plot
    fig_erp.savefig(os.path.join(figs_dir, f"{sub_name}{task}{task_stage}_erp_plot.png"), dpi=300)


    spectrum = epochs.compute_psd()
    bands = {'Theta (4-8 Hz)': (4, 8),
            'Alpha (8-12 Hz)': (8, 12),
            'Beta (12-30 Hz)': (12, 30),
            'Gamma (30-50 Hz)': (30, 50),
            'High gamma (50-80 Hz)': (50, 80)}

    fig_psd = spectrum.plot_topomap(bands=bands, vlim="joint", normalize=True)
    fig_psd.savefig(os.path.join(figs_dir, f"{sub_name}{task}{task_stage}_psd_topomap.png"), dpi=300)

    print(f'Figures for {sub_name} saved SUCCESSFULLY')

    plt.close('all')

#save the trial number data to a CSV file
trial_num_df = pd.DataFrame(trial_num_data)
trial_num_df.to_csv(os.path.join(figs_dir, f"{task[1:]}{task_stage}_TRIAL_NUM.csv"), index=False)
print(f'TRIAL NUMBER saved SUCCESSFULLY to {os.path.join(figs_dir, f"{task[1:]}{task_stage}_TRIAL_NUM.csv")}')

print(trial_num_df)
# Out:
# Creating epochs for _BL task in s1_pac_sub01...
# Opening raw data file D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub01\preproc\analysis\s1_pac_sub01_BL_reconst.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60)  idle
#     Range : 0 ... 151453 =      0.000 ...   302.906 secs
# Ready.
# Reading 0 ... 151453  =      0.000 ...   302.906 secs...
# Time sample for events 15 and 14 in trials 154-155 are not unique!
# Time sample for events 15 and 14 in trials 623-624 are not unique!
# Time sample for events 15 and 14 in trials 708-709 are not unique!
# C:\Users\a1902989\AppData\Local\Temp\ipykernel_34508\919414965.py:44: RuntimeWarning: This filename (D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub01\preproc\analysis\s1_pac_sub01_BL_reconst.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(eeg_data_path, preload=True)
# Adding metadata with 10 columns
# 120 matching events found
# Applying baseline correction (mode: mean)
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 120 events and 501 original time points ...
# 22 bad epochs dropped
# TOTAL NUMBER OF EPOCHS: 84
# Overwriting existing file.
# Overwriting existing file.
# Epochs for _BL_go in s1_pac_sub01 saved SUCCESSFULLY
#     Using multitaper spectrum estimation with 7 DPSS windows
# Averaging across epochs before plotting...
# Figures for s1_pac_sub01 saved SUCCESSFULLY
# Creating epochs for _BL task in s1_pac_sub07...
# Opening raw data file D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub07\preproc\analysis\s1_pac_sub07_BL_reconst.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60)  idle
#     Range : 0 ... 160221 =      0.000 ...   320.442 secs
# Ready.
# Reading 0 ... 160221  =      0.000 ...   320.442 secs...
# C:\Users\a1902989\AppData\Local\Temp\ipykernel_34508\919414965.py:44: RuntimeWarning: This filename (D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub07\preproc\analysis\s1_pac_sub07_BL_reconst.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(eeg_data_path, preload=True)
# Adding metadata with 10 columns
# 108 matching events found
# Applying baseline correction (mode: mean)
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 108 events and 501 original time points ...
# 5 bad epochs dropped
# TOTAL NUMBER OF EPOCHS: 98
# Overwriting existing file.
# Overwriting existing file.
# Epochs for _BL_go in s1_pac_sub07 saved SUCCESSFULLY
#     Using multitaper spectrum estimation with 7 DPSS windows
# Averaging across epochs before plotting...
# Figures for s1_pac_sub07 saved SUCCESSFULLY
# Creating epochs for _BL task in s1_pac_sub10...
# Opening raw data file D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub10\preproc\analysis\s1_pac_sub10_BL_reconst.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60)  idle
#     Range : 0 ... 162018 =      0.000 ...   324.036 secs
# Ready.
# Reading 0 ... 162018  =      0.000 ...   324.036 secs...
# Time sample for events 15 and 14 in trials 41-42 are not unique!
# Time sample for events 15 and 14 in trials 659-660 are not unique!
# C:\Users\a1902989\AppData\Local\Temp\ipykernel_34508\919414965.py:44: RuntimeWarning: This filename (D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub10\preproc\analysis\s1_pac_sub10_BL_reconst.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(eeg_data_path, preload=True)
# Adding metadata with 10 columns
# 118 matching events found
# Applying baseline correction (mode: mean)
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 118 events and 501 original time points ...
# 8 bad epochs dropped
# TOTAL NUMBER OF EPOCHS: 106
# Overwriting existing file.
# Overwriting existing file.
# Epochs for _BL_go in s1_pac_sub10 saved SUCCESSFULLY
#     Using multitaper spectrum estimation with 7 DPSS windows
# Averaging across epochs before plotting...
# Figures for s1_pac_sub10 saved SUCCESSFULLY
# Creating epochs for _BL task in s1_pac_sub11...
# Opening raw data file D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub11\preproc\analysis\s1_pac_sub11_BL_reconst.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60)  idle
#     Range : 0 ... 146134 =      0.000 ...   292.268 secs
# Ready.
# Reading 0 ... 146134  =      0.000 ...   292.268 secs...
# Time sample for events 15 and 14 in trials 84-85 are not unique!
# Time sample for events 15 and 14 in trials 96-97 are not unique!
# C:\Users\a1902989\AppData\Local\Temp\ipykernel_34508\919414965.py:44: RuntimeWarning: This filename (D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub11\preproc\analysis\s1_pac_sub11_BL_reconst.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(eeg_data_path, preload=True)
# Adding metadata with 10 columns
# 123 matching events found
# Applying baseline correction (mode: mean)
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 123 events and 501 original time points ...
# 16 bad epochs dropped
# TOTAL NUMBER OF EPOCHS: 96
# Overwriting existing file.
# Overwriting existing file.
# Epochs for _BL_go in s1_pac_sub11 saved SUCCESSFULLY
#     Using multitaper spectrum estimation with 7 DPSS windows
# Averaging across epochs before plotting...
# Figures for s1_pac_sub11 saved SUCCESSFULLY
# Creating epochs for _BL task in s1_pac_sub22...
# Opening raw data file D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub22\preproc\analysis\s1_pac_sub22_BL_reconst.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60)  idle
#     Range : 0 ... 152385 =      0.000 ...   304.770 secs
# Ready.
# Reading 0 ... 152385  =      0.000 ...   304.770 secs...
# Time sample for events 15 and 14 in trials 119-120 are not unique!
# Time sample for events 15 and 14 in trials 698-699 are not unique!
# C:\Users\a1902989\AppData\Local\Temp\ipykernel_34508\919414965.py:44: RuntimeWarning: This filename (D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub22\preproc\analysis\s1_pac_sub22_BL_reconst.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(eeg_data_path, preload=True)
# Adding metadata with 10 columns
# 118 matching events found
# Applying baseline correction (mode: mean)
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 118 events and 501 original time points ...
# 5 bad epochs dropped
# TOTAL NUMBER OF EPOCHS: 102
# Overwriting existing file.
# Overwriting existing file.
# Epochs for _BL_go in s1_pac_sub22 saved SUCCESSFULLY
#     Using multitaper spectrum estimation with 7 DPSS windows
# Averaging across epochs before plotting...
# Figures for s1_pac_sub22 saved SUCCESSFULLY
# Creating epochs for _BL task in s1_pac_sub24...
# Opening raw data file D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub24\preproc\analysis\s1_pac_sub24_BL_reconst.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60)  idle
#     Range : 0 ... 171384 =      0.000 ...   342.768 secs
# Ready.
# Reading 0 ... 171384  =      0.000 ...   342.768 secs...
# Time sample for events 14 and 15 in trials 686-687 are not unique!
# C:\Users\a1902989\AppData\Local\Temp\ipykernel_34508\919414965.py:44: RuntimeWarning: This filename (D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub24\preproc\analysis\s1_pac_sub24_BL_reconst.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(eeg_data_path, preload=True)
# Adding metadata with 10 columns
# 106 matching events found
# Applying baseline correction (mode: mean)
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 106 events and 501 original time points ...
# 6 bad epochs dropped
# TOTAL NUMBER OF EPOCHS: 98
# Overwriting existing file.
# Overwriting existing file.
# Epochs for _BL_go in s1_pac_sub24 saved SUCCESSFULLY
#     Using multitaper spectrum estimation with 7 DPSS windows
# Averaging across epochs before plotting...
# Figures for s1_pac_sub24 saved SUCCESSFULLY
# Creating epochs for _BL task in s1_pac_sub26...
# Opening raw data file D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub26\preproc\analysis\s1_pac_sub26_BL_reconst.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60)  idle
#     Range : 0 ... 178620 =      0.000 ...   357.240 secs
# Ready.
# Reading 0 ... 178620  =      0.000 ...   357.240 secs...
# C:\Users\a1902989\AppData\Local\Temp\ipykernel_34508\919414965.py:44: RuntimeWarning: This filename (D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub26\preproc\analysis\s1_pac_sub26_BL_reconst.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(eeg_data_path, preload=True)
# Adding metadata with 10 columns
# 115 matching events found
# Applying baseline correction (mode: mean)
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 115 events and 501 original time points ...
# 6 bad epochs dropped
# TOTAL NUMBER OF EPOCHS: 100
# Overwriting existing file.
# Overwriting existing file.
# Epochs for _BL_go in s1_pac_sub26 saved SUCCESSFULLY
#     Using multitaper spectrum estimation with 7 DPSS windows
# Averaging across epochs before plotting...
# Figures for s1_pac_sub26 saved SUCCESSFULLY
# Creating epochs for _BL task in s1_pac_sub29...
# Opening raw data file D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub29\preproc\analysis\s1_pac_sub29_BL_reconst.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60)  idle
#     Range : 0 ... 146749 =      0.000 ...   293.498 secs
# Ready.
# Reading 0 ... 146749  =      0.000 ...   293.498 secs...
# Time sample for events 15 and 14 in trials 41-42 are not unique!
# Time sample for events 15 and 14 in trials 77-78 are not unique!
# Time sample for events 15 and 14 in trials 368-369 are not unique!
# Time sample for events 15 and 14 in trials 530-531 are not unique!
# Time sample for events 15 and 14 in trials 700-701 are not unique!
# C:\Users\a1902989\AppData\Local\Temp\ipykernel_34508\919414965.py:44: RuntimeWarning: This filename (D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub29\preproc\analysis\s1_pac_sub29_BL_reconst.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(eeg_data_path, preload=True)
# Adding metadata with 10 columns
# 129 matching events found
# Applying baseline correction (mode: mean)
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 129 events and 501 original time points ...
# 26 bad epochs dropped
# TOTAL NUMBER OF EPOCHS: 91
# Overwriting existing file.
# Overwriting existing file.
# Epochs for _BL_go in s1_pac_sub29 saved SUCCESSFULLY
#     Using multitaper spectrum estimation with 7 DPSS windows
# Averaging across epochs before plotting...
# Figures for s1_pac_sub29 saved SUCCESSFULLY
# Creating epochs for _BL task in s1_pac_sub32...
# Opening raw data file D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub32\preproc\analysis\s1_pac_sub32_BL_reconst.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60)  idle
#     Range : 0 ... 174421 =      0.000 ...   348.842 secs
# Ready.
# Reading 0 ... 174421  =      0.000 ...   348.842 secs...
# Time sample for events 15 and 14 in trials 653-654 are not unique!
# C:\Users\a1902989\AppData\Local\Temp\ipykernel_34508\919414965.py:44: RuntimeWarning: This filename (D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub32\preproc\analysis\s1_pac_sub32_BL_reconst.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(eeg_data_path, preload=True)
# Adding metadata with 10 columns
# 80 matching events found
# Applying baseline correction (mode: mean)
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 80 events and 501 original time points ...
# 6 bad epochs dropped
# TOTAL NUMBER OF EPOCHS: 72
# Overwriting existing file.
# Overwriting existing file.
# Epochs for _BL_go in s1_pac_sub32 saved SUCCESSFULLY
#     Using multitaper spectrum estimation with 7 DPSS windows
# Averaging across epochs before plotting...
# Figures for s1_pac_sub32 saved SUCCESSFULLY
# Creating epochs for _BL task in s1_pac_sub33...
# Opening raw data file D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub33\preproc\analysis\s1_pac_sub33_BL_reconst.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60)  idle
#     Range : 0 ... 167047 =      0.000 ...   334.094 secs
# Ready.
# Reading 0 ... 167047  =      0.000 ...   334.094 secs...
# Time sample for events 14 and 15 in trials 681-682 are not unique!
# C:\Users\a1902989\AppData\Local\Temp\ipykernel_34508\919414965.py:44: RuntimeWarning: This filename (D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub33\preproc\analysis\s1_pac_sub33_BL_reconst.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(eeg_data_path, preload=True)
# Adding metadata with 10 columns
# 131 matching events found
# Applying baseline correction (mode: mean)
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 131 events and 501 original time points ...
# 30 bad epochs dropped
# TOTAL NUMBER OF EPOCHS: 97
# Overwriting existing file.
# Overwriting existing file.
# Epochs for _BL_go in s1_pac_sub33 saved SUCCESSFULLY
#     Using multitaper spectrum estimation with 7 DPSS windows
# Averaging across epochs before plotting...
# Figures for s1_pac_sub33 saved SUCCESSFULLY
# Creating epochs for _BL task in s1_pac_sub38...
# Opening raw data file D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub38\preproc\analysis\s1_pac_sub38_BL_reconst.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60)  idle
#     Range : 0 ... 156901 =      0.000 ...   313.802 secs
# Ready.
# Reading 0 ... 156901  =      0.000 ...   313.802 secs...
# Time sample for events 15 and 14 in trials 499-500 are not unique!
# C:\Users\a1902989\AppData\Local\Temp\ipykernel_34508\919414965.py:44: RuntimeWarning: This filename (D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub38\preproc\analysis\s1_pac_sub38_BL_reconst.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(eeg_data_path, preload=True)
# Adding metadata with 12 columns
# 119 matching events found
# Applying baseline correction (mode: mean)
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 119 events and 501 original time points ...
# 4 bad epochs dropped
# TOTAL NUMBER OF EPOCHS: 108
# Overwriting existing file.
# Overwriting existing file.
# Epochs for _BL_go in s1_pac_sub38 saved SUCCESSFULLY
#     Using multitaper spectrum estimation with 7 DPSS windows
# Averaging across epochs before plotting...
# Figures for s1_pac_sub38 saved SUCCESSFULLY
# Creating epochs for _BL task in s1_pac_sub43...
# Opening raw data file D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub43\preproc\analysis\s1_pac_sub43_BL_reconst.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60)  idle
#     Range : 0 ... 159134 =      0.000 ...   318.268 secs
# Ready.
# Reading 0 ... 159134  =      0.000 ...   318.268 secs...
# Time sample for events 15 and 14 in trials 100-101 are not unique!
# Time sample for events 14 and 15 in trials 381-382 are not unique!
# C:\Users\a1902989\AppData\Local\Temp\ipykernel_34508\919414965.py:44: RuntimeWarning: This filename (D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub43\preproc\analysis\s1_pac_sub43_BL_reconst.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(eeg_data_path, preload=True)
# Adding metadata with 12 columns
# 113 matching events found
# Applying baseline correction (mode: mean)
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 113 events and 501 original time points ...
# 1 bad epochs dropped
# TOTAL NUMBER OF EPOCHS: 101
# Overwriting existing file.
# Overwriting existing file.
# Epochs for _BL_go in s1_pac_sub43 saved SUCCESSFULLY
#     Using multitaper spectrum estimation with 7 DPSS windows
# Averaging across epochs before plotting...
# Figures for s1_pac_sub43 saved SUCCESSFULLY
# Creating epochs for _BL task in s1_pac_sub52...
# Opening raw data file D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub52\preproc\analysis\s1_pac_sub52_BL_reconst.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60)  idle
#     Range : 0 ... 161434 =      0.000 ...   322.868 secs
# Ready.
# Reading 0 ... 161434  =      0.000 ...   322.868 secs...
# Time sample for events 15 and 14 in trials 53-54 are not unique!
# Time sample for events 15 and 14 in trials 328-329 are not unique!
# Time sample for events 15 and 14 in trials 490-491 are not unique!
# Time sample for events 15 and 14 in trials 640-641 are not unique!
# C:\Users\a1902989\AppData\Local\Temp\ipykernel_34508\919414965.py:44: RuntimeWarning: This filename (D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub52\preproc\analysis\s1_pac_sub52_BL_reconst.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(eeg_data_path, preload=True)
# Adding metadata with 10 columns
# 119 matching events found
# Applying baseline correction (mode: mean)
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 119 events and 501 original time points ...
# 9 bad epochs dropped
# TOTAL NUMBER OF EPOCHS: 99
# Overwriting existing file.
# Overwriting existing file.
# Epochs for _BL_go in s1_pac_sub52 saved SUCCESSFULLY
#     Using multitaper spectrum estimation with 7 DPSS windows
# Averaging across epochs before plotting...
# Figures for s1_pac_sub52 saved SUCCESSFULLY
# Creating epochs for _BL task in s1_pac_sub58...
# Opening raw data file D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub58\preproc\analysis\s1_pac_sub58_BL_reconst.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60)  idle
#     Range : 0 ... 150788 =      0.000 ...   301.576 secs
# Ready.
# Reading 0 ... 150788  =      0.000 ...   301.576 secs...
# C:\Users\a1902989\AppData\Local\Temp\ipykernel_34508\919414965.py:44: RuntimeWarning: This filename (D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub58\preproc\analysis\s1_pac_sub58_BL_reconst.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(eeg_data_path, preload=True)
# Adding metadata with 13 columns
# 119 matching events found
# Applying baseline correction (mode: mean)
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 119 events and 501 original time points ...
# 1 bad epochs dropped
# TOTAL NUMBER OF EPOCHS: 105
# Overwriting existing file.
# Overwriting existing file.
# Epochs for _BL_go in s1_pac_sub58 saved SUCCESSFULLY
#     Using multitaper spectrum estimation with 7 DPSS windows
# Averaging across epochs before plotting...
# Figures for s1_pac_sub58 saved SUCCESSFULLY
# Creating epochs for _BL task in s1_pac_sub59...
# Opening raw data file D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub59\preproc\analysis\s1_pac_sub59_BL_reconst.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60)  idle
#     Range : 0 ... 158702 =      0.000 ...   317.404 secs
# Ready.
# Reading 0 ... 158702  =      0.000 ...   317.404 secs...
# C:\Users\a1902989\AppData\Local\Temp\ipykernel_34508\919414965.py:44: RuntimeWarning: This filename (D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub59\preproc\analysis\s1_pac_sub59_BL_reconst.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(eeg_data_path, preload=True)
# Adding metadata with 13 columns
# 109 matching events found
# Applying baseline correction (mode: mean)
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 109 events and 501 original time points ...
# 1 bad epochs dropped
# TOTAL NUMBER OF EPOCHS: 99
# Overwriting existing file.
# Overwriting existing file.
# Epochs for _BL_go in s1_pac_sub59 saved SUCCESSFULLY
#     Using multitaper spectrum estimation with 7 DPSS windows
# Averaging across epochs before plotting...
# Figures for s1_pac_sub59 saved SUCCESSFULLY
# Creating epochs for _BL task in s1_pac_sub61...
# Opening raw data file D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub61\preproc\analysis\s1_pac_sub61_BL_reconst.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60)  idle
#     Range : 0 ... 156274 =      0.000 ...   312.548 secs
# Ready.
# Reading 0 ... 156274  =      0.000 ...   312.548 secs...
# Time sample for events 15 and 14 in trials 103-104 are not unique!
# Time sample for events 14 and 15 in trials 579-580 are not unique!
# C:\Users\a1902989\AppData\Local\Temp\ipykernel_34508\919414965.py:44: RuntimeWarning: This filename (D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub61\preproc\analysis\s1_pac_sub61_BL_reconst.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(eeg_data_path, preload=True)
# Adding metadata with 12 columns
# 120 matching events found
# Applying baseline correction (mode: mean)
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 120 events and 501 original time points ...
# 1 bad epochs dropped
# TOTAL NUMBER OF EPOCHS: 106
# Overwriting existing file.
# Overwriting existing file.
# Epochs for _BL_go in s1_pac_sub61 saved SUCCESSFULLY
#     Using multitaper spectrum estimation with 7 DPSS windows
# Averaging across epochs before plotting...
# Figures for s1_pac_sub61 saved SUCCESSFULLY
# Creating epochs for _BL task in s1_pac_sub63...
# Opening raw data file D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub63\preproc\analysis\s1_pac_sub63_BL_reconst.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60)  idle
#     Range : 0 ... 171910 =      0.000 ...   343.820 secs
# Ready.
# Reading 0 ... 171910  =      0.000 ...   343.820 secs...
# C:\Users\a1902989\AppData\Local\Temp\ipykernel_34508\919414965.py:44: RuntimeWarning: This filename (D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub63\preproc\analysis\s1_pac_sub63_BL_reconst.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(eeg_data_path, preload=True)
# Adding metadata with 12 columns
# 98 matching events found
# Applying baseline correction (mode: mean)
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 98 events and 501 original time points ...
# 0 bad epochs dropped
# TOTAL NUMBER OF EPOCHS: 91
# Overwriting existing file.
# Overwriting existing file.
# Epochs for _BL_go in s1_pac_sub63 saved SUCCESSFULLY
#     Using multitaper spectrum estimation with 7 DPSS windows
# Averaging across epochs before plotting...
# Figures for s1_pac_sub63 saved SUCCESSFULLY
# Creating epochs for _BL task in s1_pac_sub64...
# Opening raw data file D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub64\preproc\analysis\s1_pac_sub64_BL_reconst.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60)  idle
#     Range : 0 ... 158643 =      0.000 ...   317.286 secs
# Ready.
# Reading 0 ... 158643  =      0.000 ...   317.286 secs...
# C:\Users\a1902989\AppData\Local\Temp\ipykernel_34508\919414965.py:44: RuntimeWarning: This filename (D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub64\preproc\analysis\s1_pac_sub64_BL_reconst.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(eeg_data_path, preload=True)
# Adding metadata with 12 columns
# 118 matching events found
# Applying baseline correction (mode: mean)
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 118 events and 501 original time points ...
# 0 bad epochs dropped
# TOTAL NUMBER OF EPOCHS: 107
# Overwriting existing file.
# Overwriting existing file.
# Epochs for _BL_go in s1_pac_sub64 saved SUCCESSFULLY
#     Using multitaper spectrum estimation with 7 DPSS windows
# Averaging across epochs before plotting...
# Figures for s1_pac_sub64 saved SUCCESSFULLY
# Creating epochs for _BL task in s1_pac_sub66...
# Opening raw data file D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub66\preproc\analysis\s1_pac_sub66_BL_reconst.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60)  idle
#     Range : 0 ... 145402 =      0.000 ...   290.804 secs
# Ready.
# Reading 0 ... 145402  =      0.000 ...   290.804 secs...
# Time sample for events 14 and 15 in trials 439-440 are not unique!
# Time sample for events 15 and 14 in trials 536-537 are not unique!
# C:\Users\a1902989\AppData\Local\Temp\ipykernel_34508\919414965.py:44: RuntimeWarning: This filename (D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub66\preproc\analysis\s1_pac_sub66_BL_reconst.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(eeg_data_path, preload=True)
# Adding metadata with 11 columns
# 118 matching events found
# Applying baseline correction (mode: mean)
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 118 events and 501 original time points ...
# 4 bad epochs dropped
# TOTAL NUMBER OF EPOCHS: 99
# Overwriting existing file.
# Overwriting existing file.
# Epochs for _BL_go in s1_pac_sub66 saved SUCCESSFULLY
#     Using multitaper spectrum estimation with 7 DPSS windows
# Averaging across epochs before plotting...
# Figures for s1_pac_sub66 saved SUCCESSFULLY
# Creating epochs for _BL task in s1_pac_sub67...
# Opening raw data file D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub67\preproc\analysis\s1_pac_sub67_BL_reconst.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60)  idle
#     Range : 0 ... 178652 =      0.000 ...   357.304 secs
# Ready.
# Reading 0 ... 178652  =      0.000 ...   357.304 secs...
# C:\Users\a1902989\AppData\Local\Temp\ipykernel_34508\919414965.py:44: RuntimeWarning: This filename (D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub67\preproc\analysis\s1_pac_sub67_BL_reconst.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(eeg_data_path, preload=True)
# Adding metadata with 12 columns
# 80 matching events found
# Applying baseline correction (mode: mean)
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 80 events and 501 original time points ...
# 2 bad epochs dropped
# TOTAL NUMBER OF EPOCHS: 75
# Overwriting existing file.
# Overwriting existing file.
# Epochs for _BL_go in s1_pac_sub67 saved SUCCESSFULLY
#     Using multitaper spectrum estimation with 7 DPSS windows
# Averaging across epochs before plotting...
# Figures for s1_pac_sub67 saved SUCCESSFULLY
# Creating epochs for _BL task in s1_pac_sub71...
# Opening raw data file D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub71\preproc\analysis\s1_pac_sub71_BL_reconst.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60)  idle
#     Range : 0 ... 159333 =      0.000 ...   318.666 secs
# Ready.
# Reading 0 ... 159333  =      0.000 ...   318.666 secs...
# Time sample for events 14 and 15 in trials 301-302 are not unique!
# Time sample for events 15 and 14 in trials 523-524 are not unique!
# C:\Users\a1902989\AppData\Local\Temp\ipykernel_34508\919414965.py:44: RuntimeWarning: This filename (D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub71\preproc\analysis\s1_pac_sub71_BL_reconst.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(eeg_data_path, preload=True)
# Adding metadata with 13 columns
# 117 matching events found
# Applying baseline correction (mode: mean)
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 117 events and 501 original time points ...
# 3 bad epochs dropped
# TOTAL NUMBER OF EPOCHS: 107
# Overwriting existing file.
# Overwriting existing file.
# Epochs for _BL_go in s1_pac_sub71 saved SUCCESSFULLY
#     Using multitaper spectrum estimation with 7 DPSS windows
# Averaging across epochs before plotting...
# Figures for s1_pac_sub71 saved SUCCESSFULLY
# Creating epochs for _BL task in s1_pac_sub72...
# Opening raw data file D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub72\preproc\analysis\s1_pac_sub72_BL_reconst.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60)  idle
#     Range : 0 ... 166050 =      0.000 ...   332.100 secs
# Ready.
# Reading 0 ... 166050  =      0.000 ...   332.100 secs...
# Time sample for events 15 and 14 in trials 570-571 are not unique!
# C:\Users\a1902989\AppData\Local\Temp\ipykernel_34508\919414965.py:44: RuntimeWarning: This filename (D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub72\preproc\analysis\s1_pac_sub72_BL_reconst.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(eeg_data_path, preload=True)
# Adding metadata with 12 columns
# 90 matching events found
# Applying baseline correction (mode: mean)
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 90 events and 501 original time points ...
# 0 bad epochs dropped
# TOTAL NUMBER OF EPOCHS: 85
# Overwriting existing file.
# Overwriting existing file.
# Epochs for _BL_go in s1_pac_sub72 saved SUCCESSFULLY
#     Using multitaper spectrum estimation with 7 DPSS windows
# Averaging across epochs before plotting...
# Figures for s1_pac_sub72 saved SUCCESSFULLY
# Creating epochs for _BL task in s1_pac_sub76...
# Opening raw data file D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub76\preproc\analysis\s1_pac_sub76_BL_reconst.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60)  idle
#     Range : 0 ... 159446 =      0.000 ...   318.892 secs
# Ready.
# Reading 0 ... 159446  =      0.000 ...   318.892 secs...
# C:\Users\a1902989\AppData\Local\Temp\ipykernel_34508\919414965.py:44: RuntimeWarning: This filename (D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub76\preproc\analysis\s1_pac_sub76_BL_reconst.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(eeg_data_path, preload=True)
# Adding metadata with 12 columns
# 120 matching events found
# Applying baseline correction (mode: mean)
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 120 events and 501 original time points ...
# 3 bad epochs dropped
# TOTAL NUMBER OF EPOCHS: 109
# Overwriting existing file.
# Overwriting existing file.
# Epochs for _BL_go in s1_pac_sub76 saved SUCCESSFULLY
#     Using multitaper spectrum estimation with 7 DPSS windows
# Averaging across epochs before plotting...
# Figures for s1_pac_sub76 saved SUCCESSFULLY
# Creating epochs for _BL task in s1_pac_sub77...
# Opening raw data file D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub77\preproc\analysis\s1_pac_sub77_BL_reconst.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60)  idle
#     Range : 0 ... 159238 =      0.000 ...   318.476 secs
# Ready.
# Reading 0 ... 159238  =      0.000 ...   318.476 secs...
# C:\Users\a1902989\AppData\Local\Temp\ipykernel_34508\919414965.py:44: RuntimeWarning: This filename (D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub77\preproc\analysis\s1_pac_sub77_BL_reconst.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(eeg_data_path, preload=True)
# Adding metadata with 12 columns
# 123 matching events found
# Applying baseline correction (mode: mean)
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 123 events and 501 original time points ...
# 8 bad epochs dropped
# TOTAL NUMBER OF EPOCHS: 110
# Overwriting existing file.
# Overwriting existing file.
# Epochs for _BL_go in s1_pac_sub77 saved SUCCESSFULLY
#     Using multitaper spectrum estimation with 7 DPSS windows
# Averaging across epochs before plotting...
# Figures for s1_pac_sub77 saved SUCCESSFULLY
# TRIAL NUMBER saved SUCCESSFULLY to D:\BonoKat\research project\# study 1\eeg_data\set\figures\Y\epochs\_BL\BL_go_TRIAL_NUM.csv
#              sub task_stage  trial_num
# 0   s1_pac_sub01        _go         84
# 1   s1_pac_sub07        _go         98
# 2   s1_pac_sub10        _go        106
# 3   s1_pac_sub11        _go         96
# 4   s1_pac_sub22        _go        102
# 5   s1_pac_sub24        _go         98
# 6   s1_pac_sub26        _go        100
# 7   s1_pac_sub29        _go         91
# 8   s1_pac_sub32        _go         72
# 9   s1_pac_sub33        _go         97
# 10  s1_pac_sub38        _go        108
# 11  s1_pac_sub43        _go        101
# 12  s1_pac_sub52        _go         99
# 13  s1_pac_sub58        _go        105
# 14  s1_pac_sub59        _go         99
# 15  s1_pac_sub61        _go        106
# 16  s1_pac_sub63        _go         91
# 17  s1_pac_sub64        _go        107
# 18  s1_pac_sub66        _go         99
# 19  s1_pac_sub67        _go         75
# 20  s1_pac_sub71        _go        107
# 21  s1_pac_sub72        _go         85
# 22  s1_pac_sub76        _go        109
# 23  s1_pac_sub77        _go        110

# %%
print(trial_num_df)
# Out:
#              sub task_stage  trial_num
# 0   s1_pac_sub01        _go         84
# 1   s1_pac_sub07        _go         98
# 2   s1_pac_sub10        _go        106
# 3   s1_pac_sub11        _go         96
# 4   s1_pac_sub22        _go        102
# 5   s1_pac_sub24        _go         98
# 6   s1_pac_sub26        _go        100
# 7   s1_pac_sub29        _go         91
# 8   s1_pac_sub32        _go         72
# 9   s1_pac_sub33        _go         97
# 10  s1_pac_sub38        _go        108
# 11  s1_pac_sub43        _go        101
# 12  s1_pac_sub52        _go         99
# 13  s1_pac_sub58        _go        105
# 14  s1_pac_sub59        _go         99
# 15  s1_pac_sub61        _go        106
# 16  s1_pac_sub63        _go         91
# 17  s1_pac_sub64        _go        107
# 18  s1_pac_sub66        _go         99
# 19  s1_pac_sub67        _go         75
# 20  s1_pac_sub71        _go        107
# 21  s1_pac_sub72        _go         85
# 22  s1_pac_sub76        _go        109
# 23  s1_pac_sub77        _go        110

# %% [markdown]
# ALL ELECTRODES & ALL SUBJECTS

# %%
# eeg_data_dir = 'D:\\BonoKat\\research project\\# study 1\\eeg_data\\set'
# group = 'Y'
# task = '_BL' # ['_BL', '_MAIN']
# task_stage = '_plan' # '_plan' or 'go'
# subs_dir = os.path.join(eeg_data_dir, group)

all_epochs = []

for sub_name in os.listdir(subs_dir): # os.listdir(subs_dir) OR ['s1_pac_sub00']

    preproc_dir = os.path.join(subs_dir, sub_name, 'preproc')
    analysis_dir = os.path.join(preproc_dir, 'analysis')

    epochs_data_path = os.path.join(analysis_dir, f'{sub_name}{task}_epochs{task_stage}-epo.fif')
    epochs = mne.read_epochs(epochs_data_path, preload=True)
    all_epochs.append(epochs)
# Out:
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub01\preproc\analysis\s1_pac_sub01_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 10 columns
# 84 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub07\preproc\analysis\s1_pac_sub07_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 10 columns
# 98 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub10\preproc\analysis\s1_pac_sub10_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 10 columns
# 106 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub11\preproc\analysis\s1_pac_sub11_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 10 columns
# 96 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub22\preproc\analysis\s1_pac_sub22_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 10 columns
# 102 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub24\preproc\analysis\s1_pac_sub24_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 10 columns
# 98 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub26\preproc\analysis\s1_pac_sub26_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 10 columns
# 100 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub29\preproc\analysis\s1_pac_sub29_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 10 columns
# 91 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub32\preproc\analysis\s1_pac_sub32_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 10 columns
# 72 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub33\preproc\analysis\s1_pac_sub33_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 10 columns
# 97 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub38\preproc\analysis\s1_pac_sub38_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 12 columns
# 108 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub43\preproc\analysis\s1_pac_sub43_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 12 columns
# 101 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub52\preproc\analysis\s1_pac_sub52_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 10 columns
# 99 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub58\preproc\analysis\s1_pac_sub58_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 13 columns
# 105 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub59\preproc\analysis\s1_pac_sub59_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 13 columns
# 99 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub61\preproc\analysis\s1_pac_sub61_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 12 columns
# 106 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub63\preproc\analysis\s1_pac_sub63_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 12 columns
# 91 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub64\preproc\analysis\s1_pac_sub64_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 12 columns
# 107 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub66\preproc\analysis\s1_pac_sub66_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 11 columns
# 99 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub67\preproc\analysis\s1_pac_sub67_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 12 columns
# 75 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub71\preproc\analysis\s1_pac_sub71_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 13 columns
# 107 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub72\preproc\analysis\s1_pac_sub72_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 12 columns
# 85 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub76\preproc\analysis\s1_pac_sub76_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 12 columns
# 109 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub77\preproc\analysis\s1_pac_sub77_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 12 columns
# 110 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated

# %%
len(all_epochs)
# Out:
# 24

# %%
epochs_all_subs = mne.concatenate_epochs(all_epochs)
epochs_all_subs
# Out:
# C:\Users\a1902989\AppData\Local\Temp\ipykernel_34508\1231508276.py:1: RuntimeWarning: Concatenation of Annotations within Epochs is not supported yet. All annotations will be dropped.
#   epochs_all_subs = mne.concatenate_epochs(all_epochs)
# Adding metadata with 13 columns
# 2345 matching events found
# Applying baseline correction (mode: mean)
# Created an SSP operator (subspace dimension = 1)
# <EpochsArray | 2345 events (all good), -0.5 – 0.5 s (baseline -0.5 – 0.5 s), ~546.8 MB, data loaded, with metadata,
#  'key_press': 2345>

# %%
group_save_path = f'D:\\BonoKat\\research project\\# study 1\\eeg_data\\set\\{group} group'
epochs_all_subs.save((os.path.join(group_save_path, f"{group}_ALL_SUBS{task}_epochs{task_stage}_ALL-epo.fif")), overwrite=True)

# %% [markdown]
# _________________________

# %% [markdown]
# Time-frequency

# %%
# task_stage = '_go' # '_plan' or 'go'

for sub_name in os.listdir(subs_dir): # os.listdir(subs_dir) OR ['s1_pac_sub00']
    
    print(f'Creating epochs for {task} task in {sub_name}...')

    preproc_dir = os.path.join(subs_dir, sub_name, 'preproc')
    analysis_dir = os.path.join(preproc_dir, 'analysis')
    tfr_dir = os.path.join(figs_dir, 'TFR')
    check_paths(tfr_dir)

    epochs_data_path = os.path.join(analysis_dir, f'{sub_name}{task}_epochs{task_stage}-epo.fif')
    epochs = mne.read_epochs(epochs_data_path, preload=True)

    freqs = np.logspace(*np.log10([4, 80]), num=40)
    n_cycles = freqs / 2.0  # different number of cycle per frequency
    power, itc = epochs.compute_tfr(
        method="morlet",
        freqs=freqs,
        n_cycles=n_cycles,
        average=True,
        return_itc=True,
        decim=3,
    )

    # Save time-freq analysis output
    power.save(os.path.join(analysis_dir, f"{sub_name}{task}{task_stage}_power-tfr.h5"), overwrite=True)
    itc.save(os.path.join(analysis_dir, f"{sub_name}{task}{task_stage}_itc-tfr.h5"), overwrite=True)

    # plot ITC and Power
    itc_fig = itc.plot(combine='mean', baseline=baseline_epo)[0]
    power_all_fig = power.plot(baseline=baseline_epo, mode="logratio", title='Averaged Power Across Channels', combine='mean')[0]
    power_motor_fig = power.plot(picks=['C1', 'C3', 'C5'], baseline=baseline_epo, mode="logratio", title='Averaged Power Across C1-5 Channels', combine='mean')[0]

    # save ITC and Power plots
    itc_fig.savefig(os.path.join(figs_dir, 'TFR', f"{sub_name}{task}_itc.png"), dpi=300)
    power_all_fig.savefig(os.path.join(figs_dir, 'TFR', f"{sub_name}{task}_power_all.png"), dpi=300)
    power_motor_fig.savefig(os.path.join(figs_dir, 'TFR', f"{sub_name}{task}_power_motor.png"), dpi=300)

    plt.close('all')
# Out:
# Creating epochs for _BL task in s1_pac_sub01...
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub01\preproc\analysis\s1_pac_sub01_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 10 columns
# 84 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.7s
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Creating epochs for _BL task in s1_pac_sub07...
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub07\preproc\analysis\s1_pac_sub07_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 10 columns
# 98 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.8s
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Creating epochs for _BL task in s1_pac_sub10...
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub10\preproc\analysis\s1_pac_sub10_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 10 columns
# 106 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.9s
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Creating epochs for _BL task in s1_pac_sub11...
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub11\preproc\analysis\s1_pac_sub11_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 10 columns
# 96 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.8s
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Creating epochs for _BL task in s1_pac_sub22...
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub22\preproc\analysis\s1_pac_sub22_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 10 columns
# 102 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.8s
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Creating epochs for _BL task in s1_pac_sub24...
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub24\preproc\analysis\s1_pac_sub24_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 10 columns
# 98 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.8s
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Creating epochs for _BL task in s1_pac_sub26...
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub26\preproc\analysis\s1_pac_sub26_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 10 columns
# 100 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.8s
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Creating epochs for _BL task in s1_pac_sub29...
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub29\preproc\analysis\s1_pac_sub29_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 10 columns
# 91 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.7s
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Creating epochs for _BL task in s1_pac_sub32...
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub32\preproc\analysis\s1_pac_sub32_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 10 columns
# 72 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.6s
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Creating epochs for _BL task in s1_pac_sub33...
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub33\preproc\analysis\s1_pac_sub33_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 10 columns
# 97 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.8s
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Creating epochs for _BL task in s1_pac_sub38...
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub38\preproc\analysis\s1_pac_sub38_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 12 columns
# 108 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.9s
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Creating epochs for _BL task in s1_pac_sub43...
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub43\preproc\analysis\s1_pac_sub43_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 12 columns
# 101 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.8s
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Creating epochs for _BL task in s1_pac_sub52...
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub52\preproc\analysis\s1_pac_sub52_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 10 columns
# 99 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.8s
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Creating epochs for _BL task in s1_pac_sub58...
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub58\preproc\analysis\s1_pac_sub58_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 13 columns
# 105 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.9s
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Creating epochs for _BL task in s1_pac_sub59...
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub59\preproc\analysis\s1_pac_sub59_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 13 columns
# 99 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.8s
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Creating epochs for _BL task in s1_pac_sub61...
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub61\preproc\analysis\s1_pac_sub61_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 12 columns
# 106 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.9s
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Creating epochs for _BL task in s1_pac_sub63...
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub63\preproc\analysis\s1_pac_sub63_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 12 columns
# 91 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.7s
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Creating epochs for _BL task in s1_pac_sub64...
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub64\preproc\analysis\s1_pac_sub64_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 12 columns
# 107 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.9s
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Creating epochs for _BL task in s1_pac_sub66...
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub66\preproc\analysis\s1_pac_sub66_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 11 columns
# 99 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.8s
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Creating epochs for _BL task in s1_pac_sub67...
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub67\preproc\analysis\s1_pac_sub67_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 12 columns
# 75 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.6s
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Creating epochs for _BL task in s1_pac_sub71...
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub71\preproc\analysis\s1_pac_sub71_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 13 columns
# 107 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.9s
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Creating epochs for _BL task in s1_pac_sub72...
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub72\preproc\analysis\s1_pac_sub72_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 12 columns
# 85 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.7s
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Creating epochs for _BL task in s1_pac_sub76...
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub76\preproc\analysis\s1_pac_sub76_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 12 columns
# 109 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.9s
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)
# Creating epochs for _BL task in s1_pac_sub77...
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub77\preproc\analysis\s1_pac_sub77_BL_epochs_go-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 12 columns
# 110 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.9s
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: logratio)
# Applying baseline correction (mode: logratio)

# %% [markdown]
# TF group

# %%
# group = 'O'
group_save_path = f'D:\\BonoKat\\research project\\# study 1\\eeg_data\\set\\{group} group'

sub_name = 'ALL_subs'
# task = '_BL' # ['_BL', '_MAIN']
# task_stage = '_go' # '_plan' or '_go'

figs_dir = os.path.join('D:\\BonoKat\\research project\\# study 1\\eeg_data\\set\\figures', group, 'epochs', task, 'TFR')
check_paths(figs_dir)

epochs_all_subs = mne.read_epochs(os.path.join(group_save_path, f"{group}_{sub_name}{task}_epochs{task_stage}_ALL-epo.fif"), preload=True)
epochs_all_subs
# Out:
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y group\Y_ALL_subs_BL_epochs_go_ALL-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 13 columns
# 2345 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# <EpochsFIF | 2345 events (all good), -0.5 – 0.5 s (baseline -0.5 – 0.5 s), ~546.8 MB, data loaded, with metadata,
#  'key_press': 2345>

# %%
freqs = np.logspace(*np.log10([4, 80]), num=40)
n_cycles = freqs / 2.0  # different number of cycle per frequency
baseline = (-0.5, -0.1)

power, itc = epochs_all_subs.compute_tfr(
    method="morlet",
    freqs=freqs,
    n_cycles=n_cycles,
    average=True,
    return_itc=True,
    decim=3,
    n_jobs=-1
)

# Save time-freq analysis output
power.save(os.path.join(group_save_path, f"{group}_{sub_name}{task}{task_stage}_power-tfr.h5"), overwrite=True)
itc.save(os.path.join(group_save_path, f"{group}_{sub_name}{task}{task_stage}_itc-tfr.h5"), overwrite=True)

# plot ITC and Power
itc_fig = itc.plot(combine='mean', baseline=baseline, title=f'Group: {group}: Finger-tapping task: {task_stage[1:]}. ITC', cmap='magma')[0]
power_all_fig = power.plot(baseline=baseline, mode="logratio", title=f'Group: {group}: Finger-tapping task: {task_stage[1:]}. Averaged Power', combine='mean', cmap='magma')[0]

# save ITC and Power plots
itc_fig.savefig(os.path.join(figs_dir, f"{group}_{sub_name}{task}{task_stage}_itc.png"), dpi=300)
power_all_fig.savefig(os.path.join(figs_dir, f"{group}_{sub_name}{task}{task_stage}_power_all.png"), dpi=300)

# plt.close('all')
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 20 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  54 out of  60 | elapsed:    9.0s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    9.1s finished
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: logratio)

# %%
# from mne.time_frequency import read_tfrs
# task_stage = '_go'
# power = read_tfrs(os.path.join(group_save_path, 'ALL_subs_BL_go_power-tfr.h5'))
# itc = read_tfrs(os.path.join(group_save_path, 'ALL_subs_BL_go_itc-tfr.h5'))

# # plot ITC and Power
# itc_fig = itc.plot(combine='mean', baseline=baseline, title=f'Group: {group}: Finger-tapping task: {task_stage[1:]}. ITC', cmap='magma')[0]
# power_all_fig = power.plot(baseline=baseline, mode="logratio", title=f'Group: {group}: Finger-tapping task: {task_stage[1:]}. Averaged Power', combine='mean', cmap='magma')[0]

# # save ITC and Power plots
# itc_fig.savefig(os.path.join(figs_dir, f"{group}_{sub_name}{task}{task_stage}_itc.png"), dpi=300)
# power_all_fig.savefig(os.path.join(figs_dir, f"{group}_{sub_name}{task}{task_stage}_power_all.png"), dpi=300)

# %% [markdown]
# _________________________________

# %% [markdown]
# **SINGLE SUB**

# %%
# set EEG data path, group, task and subject
eeg_data_dir = 'D:\\BonoKat\\research project\\# study 1\\eeg_data\\set'
group = 'Y'
sub_name = 's1_pac_sub24' # specify the subject you want to analyse 's1_pac_sub52'

preproc_dir = os.path.join(eeg_data_dir, group, sub_name, 'preproc')
filt_dir = os.path.join(preproc_dir, 'filt')
analysis_dir = os.path.join(preproc_dir, 'analysis')
task = '_BL'

eeg_data_path = os.path.join(analysis_dir, f'{sub_name}{task}_reconst.fif')
raw = mne.io.read_raw_fif(eeg_data_path, preload=True)

raw.plot()

# # Open events from pickle file
# with open(os.path.join(filt_dir, f'{sub_name}{task}_events.pkl'), 'rb') as pickle_file:
#     events = pickle.load(pickle_file)

# # check if event time samples are unique
# for i in range(len(events[0]) - 1):
#     if events[0][i, 0] == events[0][i+1, 0]:
#         print(f'Time sample for events {events[0][i, 2]} and {events[0][i+1, 2]} in trials {i}-{i+1} are not unique!')
#         events[0][i+1, 0] = events[0][i, 0] + 1
# Out:
# Opening raw data file D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub24\preproc\analysis\s1_pac_sub24_BL_reconst.fif...
# C:\Users\a1902989\AppData\Local\Temp\ipykernel_4020\1306293854.py:12: RuntimeWarning: This filename (D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub24\preproc\analysis\s1_pac_sub24_BL_reconst.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(eeg_data_path, preload=True)
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60)  idle
#     Range : 0 ... 171384 =      0.000 ...   342.768 secs
# Ready.
# Reading 0 ... 171384  =      0.000 ...   342.768 secs...
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 1920x1017 with 5 Axes>
# Channels marked as bad:
# none

# %%
events[1].keys()
# Out:
# dict_keys(['0, Impedance', 'new_trial', 'start_instr', 'break_instr', 'finish_instr', 'prepare', 'isi1', 'go', 'isi2', 'key_press'])

# %%
# metadata for each epoch shall include events from the range: [0.0, 1.5] s,
# i.e. starting with stimulus onset and expanding beyond the end of the epoch
metadata_tmin, metadata_tmax = -0.5, 1

# events of interest
row_events = ['prepare']

# auto-create metadata:
# this also returns a new events array and an event_id dictionary. we'll see
# later why this is important
metadata, events_plan, event_id_plan = mne.epochs.make_metadata(
    events=events[0],
    event_id=events[1],
    tmin=metadata_tmin,
    tmax=metadata_tmax,
    sfreq=raw.info["sfreq"],
    row_events=row_events
)

# let's look at what we got!
metadata
# Out:
#     event_name  0, Impedance  new_trial  break_instr  finish_instr  prepare  \
# 2      prepare           NaN     -0.060          NaN           NaN      0.0
# 8      prepare           NaN     -0.016          NaN           NaN      0.0
# 14     prepare           NaN     -0.016          NaN           NaN      0.0
# 20     prepare           NaN     -0.016          NaN           NaN      0.0
# 26     prepare           NaN     -0.016          NaN           NaN      0.0
# ..         ...           ...        ...          ...           ...      ...
# 687    prepare           NaN     -0.018          NaN           NaN      0.0
# 693    prepare           NaN     -0.016          NaN           NaN      0.0
# 699    prepare           NaN     -0.018          NaN           NaN      0.0
# 705    prepare           NaN     -0.016          NaN           NaN      0.0
# 711    prepare           NaN     -0.016          NaN           NaN      0.0
#
#      isi1  go  isi2  key_press
# 2     NaN NaN   NaN        NaN
# 8     NaN NaN   NaN        NaN
# 14    NaN NaN   NaN        NaN
# 20    NaN NaN   NaN        NaN
# 26    NaN NaN   NaN        NaN
# ..    ...  ..   ...        ...
# 687   NaN NaN   NaN        NaN
# 693   NaN NaN   NaN        NaN
# 699   NaN NaN   NaN        NaN
# 705   NaN NaN   NaN        NaN
# 711   NaN NaN   NaN        NaN
#
# [119 rows x 10 columns]

# %%
epochs_tmin, epochs_tmax = -0.5, 0.5  # epochs range: [-0.1, 0.4] s
baseline = (epochs_tmin, -0.1)

epochs_plan = mne.Epochs(
    raw=raw,
    tmin=epochs_tmin,
    tmax=epochs_tmax,
    events=events_plan,
    event_id=event_id_plan,
    baseline=baseline,
    metadata=metadata,
    reject_by_annotation=True,
    preload=True,
)
# Out:
# Adding metadata with 10 columns
# 119 matching events found
# Applying baseline correction (mode: mean)
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 119 events and 501 original time points ...
# 20 bad epochs dropped

# %%
epochs_plan = epochs_plan["go.isna() & isi2.isna() & key_press.isna()"]
epochs_plan
# Out:
# <Epochs | 99 events (all good), -0.5 – 0.5 s (baseline -0.5 – -0.1 s), ~23.2 MB, data loaded, with metadata,
#  'prepare': 99>

# %%
epochs_plan.plot(events=events[0], n_channels=64)

# %%
epochs_plan.average().plot(gfp=True, spatial_colors=True)

# %%
epochs_plan.compute_psd().plot(exclude="bads", amplitude=True)

spectrum = epochs_plan.compute_psd()
spectrum.plot_topomap()
# Out:
#     Using multitaper spectrum estimation with 7 DPSS windows
# Plotting amplitude spectral density (dB=True).
# Averaging across epochs before plotting...
#     Using multitaper spectrum estimation with 7 DPSS windows
# Averaging across epochs before plotting...

# %%
spectrum = epochs_plan.compute_psd()
bands = {'Theta (4-8 Hz)': (4, 8),
         'Alpha (8-12 Hz)': (8, 12),
         'Beta (12-30 Hz)': (12, 30),
         'Gamma (30-50 Hz)': (30, 50),
         'High gamma (50-80 Hz)': (50, 80)}

spectrum.plot_topomap(bands=bands, vlim="joint", normalize=True)
# Out:
#     Using multitaper spectrum estimation with 7 DPSS windows
# Averaging across epochs before plotting...

# %%
layout = mne.channels.find_layout(epochs_plan.info, ch_type="eeg")
epochs_plan.plot_topo_image(
    layout=layout, fig_facecolor="w", font_color="k", sigma=1
)

# %%
epo_alpha = epochs_plan.copy().filter(l_freq=8, h_freq=12, n_jobs=-1)
epo_beta = epochs_plan.copy().filter(l_freq=12, h_freq=30, n_jobs=-1)
# Out:
# Setting up band-pass filter from 8 - 12 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 12.00 Hz
# - Upper transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 13.50 Hz)
# - Filter length: 825 samples (1.650 s)
# C:\Users\a1902989\AppData\Local\Temp\ipykernel_31684\3699951318.py:1: RuntimeWarning: filter_length (825) is longer than the signal (501), distortion is likely. Reduce filter length or filter a longer signal.
#   epo_alpha = epochs_plan.copy().filter(l_freq=8, h_freq=12, n_jobs=-1)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 20 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done 1786 tasks      | elapsed:    3.2s
# Setting up band-pass filter from 12 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 551 samples (1.102 s)
# [Parallel(n_jobs=-1)]: Done 5484 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done 5940 out of 5940 | elapsed:    3.4s finished
# C:\Users\a1902989\AppData\Local\Temp\ipykernel_31684\3699951318.py:2: RuntimeWarning: filter_length (551) is longer than the signal (501), distortion is likely. Reduce filter length or filter a longer signal.
#   epo_beta = epochs_plan.copy().filter(l_freq=12, h_freq=30, n_jobs=-1)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 20 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 108 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 2796 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 5532 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 5940 out of 5940 | elapsed:    0.3s finished

# %%
epo_alpha["prepare"].plot_topo_image(
    layout=layout, fig_facecolor="w", font_color="k", sigma=1,
    title='Planning: Alpha'
)
epo_beta["prepare"].plot_topo_image(
    layout=layout, fig_facecolor="w", font_color="k", sigma=1,
    title='Planning: Beta'
)

# %% [markdown]
# __________________________

# %% [markdown]
# TIME-FREQUENCY

# %%
freqs = np.logspace(*np.log10([4, 80]), num=40)
n_cycles = freqs / 2.0  # different number of cycle per frequency
power, itc = epochs_plan.compute_tfr(
    method="morlet",
    freqs=freqs,
    n_cycles=n_cycles,
    average=True,
    return_itc=True,
    decim=3,
)
# Out:
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.8s

# %%
itc.plot(combine='mean', baseline=baseline)

# %%
power.plot(baseline=baseline, mode="logratio", title='Averaged Power Across Channels', combine='mean')
power.plot(picks=['C1', 'C3', 'C5'], baseline=baseline, mode="logratio", title='Averaged Power Across C1-5 Channels', combine='mean')

# %% [markdown]
# ----------------------

# %% [markdown]
# PAC DRAFTS

# %%
import numpy as np
from scipy.io import loadmat

from tensorpac import Pac, EventRelatedPac, PreferredPhase
from tensorpac.utils import PeakLockedTF, PSD, ITC, BinAmplitude

# %% [markdown]
# my data

# %%
eeg_data_dir = 'D:\\BonoKat\\research project\\# study 1\\eeg_data\\set'
group = 'Y'
task = '_BL' # ['_BL', '_MAIN']
task_stage = '_plan' # '_plan' or '_go'

subs_dir = os.path.join(eeg_data_dir, group)
figs_dir = os.path.join(eeg_data_dir, 'figures', group, 'epochs', task, task_stage)
check_paths(figs_dir)

sub_name = 's1_pac_sub01'

preproc_dir = os.path.join(subs_dir, sub_name, 'preproc')
analysis_dir = os.path.join(preproc_dir, 'analysis')

epochs_data_path = os.path.join(analysis_dir, f'{sub_name}{task}_epochs{task_stage}-epo.fif')
epochs = mne.read_epochs(epochs_data_path, preload=True)
epochs
# Out:
# Reading D:\BonoKat\research project\# study 1\eeg_data\set\Y\s1_pac_sub07\preproc\analysis\s1_pac_sub07_BL_epochs_plan-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 60) active
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 10 columns
# 102 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# <EpochsFIF | 102 events (all good), -0.5 – 0.5 s (baseline -0.5 – -0.1 s), ~23.9 MB, data loaded, with metadata,
#  'prepare': 102>

# %%
pac_figs_dir = os.path.join(eeg_data_dir, 'figures', 'PAC')
check_paths(pac_figs_dir)

# %%
# Load the data from an MNE Epochs object (e.g., shape: epochs x channels x time)
data = epochs.pick("eeg").get_data()[:,4,:]  # Shape: (n_epochs, n_channels, n_times) C3
# data = np.mean(epochs.get_data(), axis=1)
sf = epochs.info['sfreq']  # Sampling frequency
times = epochs.times

# Initialize PAC object
# pac = Pac(idpac=(1, 2, 3), f_pha=(2, 12, 1), f_amp=(20, 80, 5), dcomplex='wavelet')

print(f"DATA: (n_trials, n_times)={data.shape}; SAMPLING FREQUENCY={sf}Hz; "
      f"TIME VECTOR: n_times={len(times)}")
# Out:
# DATA: (n_trials, n_times)=(99, 501); SAMPLING FREQUENCY=500.0Hz; TIME VECTOR: n_times=501

# %%
plt.figure(figsize=(8, 6))
plt.plot(times, data.mean(0))
plt.autoscale(axis='x', tight=True)
plt.title("Mean raw data across trials of C3 electrode", fontsize=18)
plt.xlabel('Times (in seconds)', fontsize=15)
plt.ylabel('V', fontsize=15)
# Out:
# Text(0, 0.5, 'V')

# %%
itc = ITC(data, sf, f_pha=(2, 20, 1, .2), dcomplex='wavelet')
# Out:
# Inter-Trials Coherence (ITC)
#     extracting 85 phases

# %%
itc.plot(times=times, cmap='plasma', fz_labels=15, fz_title=18)
plt.show()

# %%
psd = PSD(data, sf)
psd.plot()

# %%
rp_obj = EventRelatedPac(f_pha=[8, 12], f_amp=(30, 80, 2, 0.5))
erpac = rp_obj.filterfit(sf, data, method='gc', smooth=100)

# %%
plt.figure(figsize=(8, 6))
rp_obj.pacplot(erpac.squeeze(), times, rp_obj.yvec, xlabel='Time',
               ylabel='Amplitude frequency (Hz)',
               title='Event-Related PAC theta-gamma',
               fz_labels=15, fz_title=18)

plt.show()

# %%
peak = PeakLockedTF(data, sf, cue=0., times=times, f_pha=[8, 12],
                    f_amp=(30, 80, 2, 0.5))

# %%
plt.figure(figsize=(8, 8))
ax_1, ax_2 = peak.plot(zscore=True, baseline=(0, 250), cmap='Spectral_r',
                       vmin=-1, vmax=2)
plt.title('Peak-locked TF: theta-gamma')
plt.tight_layout()
plt.show()

# %% [markdown]
# rest vs plan

# %%
p_obj = Pac(idpac=(6, 0, 0), f_pha=(3, 9, 2, .1), f_amp=(30, 80, 2, 0.5))
# extract all of the phases and amplitudes
pha_p = p_obj.filter(sf, data, ftype='phase')
amp_p = p_obj.filter(sf, data, ftype='amplitude')
# define time indices where rest, planning and execution are defined
time_rest = slice(0, 250)
time_prep = slice(250, 500)

# define phase / amplitude during rest / planning / execution
pha_rest, amp_rest = pha_p[..., time_rest], amp_p[..., time_rest]
pha_prep, amp_prep = pha_p[..., time_prep], amp_p[..., time_prep]

# compute PAC inside rest, planning, and execution
pac_rest = p_obj.fit(pha_rest, amp_rest).mean(-1)
pac_prep = p_obj.fit(pha_prep, amp_prep).mean(-1)
# Out:
# Phase Amplitude Coupling object defined
#     true PAC estimation using Gaussian Copula PAC (gcPac)
#     true PAC estimation using Gaussian Copula PAC (gcPac)

# %%
vmax = np.max([pac_rest.max(), pac_prep.max()])
kw = dict(vmax=vmax, vmin=.04, cmap='viridis')
plt.figure(figsize=(14, 4))
plt.subplot(121)
p_obj.comodulogram(pac_rest, title="PAC Rest [-0.5, 0]s", **kw)
plt.subplot(122)
p_obj.comodulogram(pac_prep, title="PAC Planning [0, 0.5]s", **kw)
plt.ylabel('')
plt.tight_layout()
plt.show()

# %% [markdown]
# stats

# %%
# still using the Gaussian-Copula PAC but this time, we also select the method
# for computing the permutations
p_obj.idpac = (6, 2, 0)
# compute pac and 200 surrogates
pac_prep = p_obj.fit(pha_p[..., time_prep], amp_p[..., time_prep], n_perm=200,
                     random_state=0)
# get the p-values
mcp = 'maxstat'
pvalues = p_obj.infer_pvalues(p=0.05, mcp=mcp)
# Out:
#     true PAC estimation using Gaussian Copula PAC (gcPac)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=0)
#     infer p-values at (p=0.05, mcp=maxstat)
#     infer p-values at (p=0.05, mcp=maxstat)

# %%
# sphinx_gallery_thumbnail_number = 7
plt.figure(figsize=(8, 6))
title = (r"Significant theta$\Leftrightarrow$gamma coupling occurring during "
         f"the motor planning phase\n(p<0.05, {mcp}-corrected for multiple "
          "comparisons)")
# plot the non-significant pac in gray
pac_prep_ns = pac_prep.mean(-1).copy()
pac_prep_ns[pvalues < .05] = np.nan
p_obj.comodulogram(pac_prep_ns, cmap='gray', vmin=np.nanmin(pac_prep_ns),
                   vmax=np.nanmax(pac_prep_ns), colorbar=False)
# plot the significant pac in color
pac_prep_s = pac_prep.mean(-1).copy()
pac_prep_s[pvalues >= .05] = np.nan
p_obj.comodulogram(pac_prep_s, cmap='Spectral_r', vmin=np.nanmin(pac_prep_s),
                   vmax=np.nanmax(pac_prep_s), title=title)
plt.gca().invert_yaxis()
plt.show()
# Out:
# C:\Users\a1902989\AppData\Local\Temp\ipykernel_12828\922743022.py:14: RuntimeWarning: All-NaN slice encountered
#   p_obj.comodulogram(pac_prep_s, cmap='Spectral_r', vmin=np.nanmin(pac_prep_s),
# C:\Users\a1902989\AppData\Local\Temp\ipykernel_12828\922743022.py:15: RuntimeWarning: All-NaN slice encountered
#   vmax=np.nanmax(pac_prep_s), title=title)

# %%
width, step = 3, .2
theta = [3, 9]
alpha = [6, 14]
gamma_set = (30, 80, 2, 0.5)

# %%
# Extract only EEG channel names from the Epochs object
eeg_channel_names = epochs_all_subs.copy().pick("eeg").ch_names
print(eeg_channel_names)
# Out:
# ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'Iz', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'F1', 'F2', 'C1', 'C2', 'P1', 'P2', 'AF3', 'AF4', 'FC3', 'FC4', 'CP3', 'CP4', 'PO3', 'PO4', 'F5', 'F6', 'C5', 'C6', 'P5', 'P6', 'AF7', 'AF8', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Fpz', 'CPz', 'POz', 'Oz']

# %%
sf = epochs_all_subs.info['sfreq']  # Sampling frequency
times = epochs_all_subs.times

# %%
pac_figs_dir = os.path.join(eeg_data_dir, 'figures', 'PAC', task)
check_paths(pac_figs_dir)

# %%
sub_name = 'ALL_subs'

for i in range(len(eeg_channel_names)):
    # Load the data from an MNE Epochs object (e.g., shape: epochs x channels x time)
    data = epochs_all_subs.pick("eeg").get_data()[:,i,:]  # Shape: (n_epochs, n_channels, n_times)

    print(f"DATA: (n_trials, n_times)={data.shape}; SAMPLING FREQUENCY={sf}Hz; "
        f"TIME VECTOR: n_times={len(times)}")
    
    # MEAN RAW data from the electrode - plot
    fig = plt.figure(figsize=(8, 6))
    plt.plot(times, data.mean(0))
    plt.autoscale(axis='x', tight=True)
    plt.title(f"Mean raw data across trials of {eeg_channel_names[i]} electrode", fontsize=18)
    plt.xlabel('Times (in seconds)', fontsize=15)
    plt.ylabel('V', fontsize=15)

    fig.savefig(os.path.join(pac_figs_dir, f"{sub_name}_mean_raw_{eeg_channel_names[i]}.png"), dpi=300, bbox_inches='tight')
    fig.savefig(os.path.join(pac_figs_dir, f"{sub_name}_mean_raw_{eeg_channel_names[i]}.fig"), dpi=300, bbox_inches='tight')
    plt.close(fig)

    # inter-trial coherence (ITC) ans power spectrum density (PSD) - plots
    itc = ITC(data, sf, f_pha=(2, 30, 1, .2), dcomplex='wavelet')
    ax = itc.plot(times=times, cmap='plasma', fz_labels=15, fz_title=18)
    ax.set_title(f"ITC Plot_{eeg_channel_names[i]}", fontsize=18)
    fig = ax.get_figure()  # Get the parent figure from the Axes object
    fig.savefig(os.path.join(pac_figs_dir, f"{sub_name}_ITC_{eeg_channel_names[i]}.png"), dpi=300, bbox_inches='tight')
    fig.savefig(os.path.join(pac_figs_dir, f"{sub_name}_ITC_{eeg_channel_names[i]}.fig"), dpi=300, bbox_inches='tight')
    plt.close(fig)

    psd = PSD(data, sf)
    ax = psd.plot()
    ax.set_title(f"PSD Plot_{eeg_channel_names[i]}", fontsize=18)
    fig = ax.get_figure()
    fig.savefig(os.path.join(pac_figs_dir, f"{sub_name}_PSD_{eeg_channel_names[i]}.png"), dpi=300, bbox_inches='tight')
    fig.savefig(os.path.join(pac_figs_dir, f"{sub_name}_PSD_{eeg_channel_names[i]}.fig"), dpi=300, bbox_inches='tight')
    plt.close(fig)

    for j in [theta, alpha]:
        print(j)

        if j == theta:
            phase_name = 'theta'
        else:
            phase_name = 'alpha'

        # Event-related PAC - plot
        rp_obj = EventRelatedPac(f_pha=j, f_amp=gamma_set)
        erpac = rp_obj.filterfit(sf, data, method='gc', smooth=100)

        plt.figure(figsize=(8, 6))
        ax = rp_obj.pacplot(erpac.squeeze(), times, rp_obj.yvec, xlabel='Time',
                    ylabel='Amplitude frequency (Hz)',
                    title=f'{eeg_channel_names[i]}: Event-Related PAC {phase_name}-gamma',
                    fz_labels=15, fz_title=18)
        fig = ax.get_figure()
        fig.savefig(os.path.join(pac_figs_dir, f"{sub_name}_ERPac_{phase_name}_{eeg_channel_names[i]}.png"), dpi=300, bbox_inches='tight')
        fig.savefig(os.path.join(pac_figs_dir, f"{sub_name}_ERPac_{phase_name}_{eeg_channel_names[i]}.fig"), dpi=300, bbox_inches='tight')
        plt.close(fig)

        # time-frequency map based on phase peak - plot
        peak = PeakLockedTF(data, sf, cue=0., times=times, f_pha=j, f_amp=gamma_set)
        plt.figure(figsize=(8, 8))
        ax = peak.plot(zscore=True, baseline=(0, 250), cmap='Spectral_r',
                            vmin=-1, vmax=2)[0]
        plt.title(f'{eeg_channel_names[i]}: Peak-locked TF: {phase_name}-gamma')
        plt.tight_layout()
        fig = ax.get_figure()
        fig.savefig(os.path.join(pac_figs_dir, f"{sub_name}_peak_lockedTF_{phase_name}_{eeg_channel_names[i]}.png"), dpi=300, bbox_inches='tight')
        fig.savefig(os.path.join(pac_figs_dir, f"{sub_name}_peak_lockedTF_{phase_name}_{eeg_channel_names[i]}.fig"), dpi=300, bbox_inches='tight')
        plt.close(fig)


        # # PAC for planning
        # j[:] = [*j, width, step]
        phase = tuple((*j, width, step))
        print(phase)

        p_obj = Pac(idpac=(6, 0, 0), f_pha=phase, f_amp=gamma_set)
        # extract all of the phases and amplitudes
        pha_p = p_obj.filter(sf, data, ftype='phase')
        amp_p = p_obj.filter(sf, data, ftype='amplitude')

        # define time indices where planning is defined
        time_all = slice(250, 500)

        # define phase / amplitude during planning
        pha_prep, amp_prep = pha_p[..., time_all], amp_p[..., time_all]

        # compute PAC inside planning
        pac_prep = p_obj.fit(pha_prep, amp_prep).mean(-1)

        vmax = np.max(pac_prep.max())
        kw = dict(vmax=vmax, vmin=.04, cmap='viridis')
        plt.figure(figsize=(8, 6))
        ax = p_obj.comodulogram(pac_prep, title="PAC Planning", **kw)
        fig = ax.get_figure()
        plt.ylabel('')
        plt.tight_layout()
        fig.savefig(os.path.join(pac_figs_dir, f"{sub_name}_PAC_plan_{phase_name}_{eeg_channel_names[i]}.png"), dpi=300, bbox_inches='tight')
        fig.savefig(os.path.join(pac_figs_dir, f"{sub_name}_PAC_plan_{phase_name}_{eeg_channel_names[i]}.fig"), dpi=300, bbox_inches='tight')
        plt.close(fig)


        # # STATISTICS
        # using the Gaussian-Copula PAC but this time, we also select the method
        # for computing the permutations
        p_obj.idpac = (6, 2, 0)
        # compute pac and 200 surrogates
        pac_prep = p_obj.fit(pha_p[..., time_all], amp_p[..., time_all], n_perm=200,
                             random_state=0)
        # get the p-values
        mcp = 'maxstat'
        pvalues = p_obj.infer_pvalues(p=0.05, mcp=mcp)

        # sphinx_gallery_thumbnail_number = 7
        plt.figure(figsize=(8, 6))
        title = (f'''Significant {phase_name}-gamma coupling\n
                 occurring during the motor planning phase\n
                 (p<0.05, {mcp}-corrected for multiple comparisons''')

        # plot the non-significant pac in gray
        pac_prep_ns = pac_prep.mean(-1).copy()
        pac_prep_ns[pvalues < .05] = np.nan
        p_obj.comodulogram(pac_prep_ns, cmap='gray', vmin=np.nanmin(pac_prep_ns),
                           vmax=np.nanmax(pac_prep_ns), colorbar=False)
        
        # plot the significant pac in color
        pac_prep_s = pac_prep.mean(-1).copy()
        pac_prep_s[pvalues >= .05] = np.nan
        ax = p_obj.comodulogram(pac_prep_s, cmap='Spectral_r', vmin=np.nanmin(pac_prep_s),
                           vmax=np.nanmax(pac_prep_s), title=title)
        plt.gca().invert_yaxis()
        fig = ax.get_figure()
        fig.savefig(os.path.join(pac_figs_dir, f"{sub_name}_PAC_STATS_{phase_name}_{eeg_channel_names[i]}.png"), dpi=300, bbox_inches='tight')
        fig.savefig(os.path.join(pac_figs_dir, f"{sub_name}_PAC_STATS_{phase_name}_{eeg_channel_names[i]}.fig"), dpi=300, bbox_inches='tight')
        plt.close(fig)

# %%
os.path.join(pac_figs_dir, f"{sub_name}_PAC_STATS_{phase_name}_{eeg_channel_names[i]}.png")
# Out:
# 'D:\\BonoKat\\research project\\# study 1\\eeg_data\\set\\figures\\PAC\\s1_pac_sub01_PAC_STATS_theta_Fp2.png'

# %%
print(f"Electrode: {eeg_channel_names[i]}, Phase shape: {pha_p.shape}, Amplitude shape: {amp_p.shape}")
# Out:
# Electrode: Fp2, Phase shape: (5, 99, 501), Amplitude shape: (96, 99, 501)

# %%
pha_p.shape
# Out:
# (11, 99, 501)

# %%
if pha_p.ndim == 3:  # Check if the phase data is in the correct shape
    pha_p = np.deg2rad(pha_p)  # Convert phase to radians

# %%
fig = plt.figure(figsize=(8, 6))
plt.plot(times, data.mean(0))
plt.autoscale(axis='x', tight=True)
plt.title("Mean raw data across trials of C3 electrode", fontsize=18)
plt.xlabel('Times (in seconds)', fontsize=15)
plt.ylabel('V', fontsize=15)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[103], line 2
#       1 fig = plt.figure(figsize=(8, 6))
# ----> 2 fig.plot(times, data.mean(0))
#       3 fig.autoscale(axis='x', tight=True)
#       4 fig.title("Mean raw data across trials of C3 electrode", fontsize=18)
#
# AttributeError: 'Figure' object has no attribute 'plot'

# %%
electrodes = zip(len(epochs.get_data()[0,:,0]))

# %% [markdown]
# stopped here

# %% [markdown]
# __________________

# %%
pac_results = []
for i in range(data.shape[1]):  # Loop over channels
    pac_result = pac.filterfit(sf, data[:, i, :])  # Compute PAC on each channel
    pac_results.append(pac_result)  # Append results for each channel
# Out:
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=9309)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=7288)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=698)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=2364)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=6423)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=9426)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=2473)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=8414)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=2408)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=7013)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=6826)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=7562)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=4737)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=6149)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=2945)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=665)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=6376)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=233)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=4150)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=2174)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=5209)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=8159)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=8000)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=389)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=1610)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=6634)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=9926)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=5101)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=8658)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=5451)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=1635)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=8815)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=2560)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=3434)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=9979)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=1245)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=5329)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=2506)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=8199)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=401)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=5548)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=1773)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=8004)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=6373)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=5277)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=2404)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=6836)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=3918)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=8856)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=3459)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=1051)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=9990)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=2468)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=4826)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=6528)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=5415)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=743)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=8506)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=9582)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=1501)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)
#     extract phases (n_pha=2) and amplitudes (n_amps=2)
#     true PAC estimation using Mean Vector Length (MVL, Canolty et al. 2006)
#     compute surrogates (Swap amplitude time blocks (Bahramisharif et al. 2013), 200 permutations, random_state=8249)
#     infer p-values at (p=0.05, mcp=maxstat)
#     normalize true PAC estimation by surrogates (Substract then divide by the mean of surrogates)

# %%
len(pac_results)
# Out:
# 61

# %%
pac_results[0].shape
# Out:
# (2, 2, 110)

# %%
epochs.info['ch_names']
# Out:
# ['Fp1',
#  'Fp2',
#  'F3',
#  'F4',
#  'C3',
#  'C4',
#  'P3',
#  'P4',
#  'O1',
#  'O2',
#  'F7',
#  'F8',
#  'T7',
#  'T8',
#  'P7',
#  'P8',
#  'Fz',
#  'Cz',
#  'Pz',
#  'Iz',
#  'FC1',
#  'FC2',
#  'CP1',
#  'CP2',
#  'FC5',
#  'FC6',
#  'CP5',
#  'CP6',
#  'F1',
#  'F2',
#  'C1',
#  'C2',
#  'P1',
#  'P2',
#  'AF3',
#  'AF4',
#  'FC3',
#  'FC4',
#  'CP3',
#  'CP4',
#  'PO3',
#  'PO4',
#  'F5',
#  'F6',
#  'C5',
#  'C6',
#  'P5',
#  'P6',
#  'AF7',
#  'AF8',
#  'FT7',
#  'FT8',
#  'TP7',
#  'TP8',
#  'PO7',
#  'PO8',
#  'Fpz',
#  'CPz',
#  'POz',
#  'Oz',
#  'BIP3']

# %%
type(pac)
# Out:
# tensorpac.pac.Pac

# %%
pac_result[0, :, 0]
# Out:
# array([ 0.27716964, -0.54190301])

# %%
# Example: Select the first phase and amplitude frequency
phase_idx = 0  # Index for the phase frequency you want to visualize
amp_idx = 0    # Index for the amplitude frequency you want to visualize

for i, pac_result in enumerate(pac_results):
    xvec = pac.f_pha
    yvec = pac.f_amp

    # Select specific indices for phase and amplitude
    pac_result_selected = pac_result[phase_idx, :, :]  # Shape: (time_points)

    pac.pacplot(pac_result_selected, xvec=xvec, yvec=yvec, title=f"PAC for Channel {i}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[70], line 12
#       9 # Select specific indices for phase and amplitude
#      10 pac_result_selected = pac_result[phase_idx, :, :]  # Shape: (time_points)
# ---> 12 pac.pacplot(pac_result_selected, xvec=xvec, yvec=yvec, title=f"PAC for Channel {i}")
#
# File d:\BonoKat\research project\# study 1\venv\Lib\site-packages\tensorpac\visu.py:124, in _PacVisual.pacplot(self, pac, xvec, yvec, xlabel, ylabel, cblabel, title, fz_labels, fz_title, fz_cblabel, cmap, vmin, vmax, under, over, bad, pvalues, p, interp, rmaxis, dpaxis, plotas, ncontours, levels, levelcmap, polar, colorbar, y, subplot)
#     122 toplot = pac.data if levels is not None else pac
#     123 if plotas is 'imshow':
# --> 124     im = plt.imshow(toplot, aspect='auto', cmap=cmap, origin='upper',
#     125                     vmin=vmin, vmax=vmax, interpolation='none',
#     126                     extent=[xvec[0], xvec[-1], yvec[-1], yvec[0]])
#     127     plt.gca().invert_yaxis()
#     128 elif plotas is 'contour':
#
# File d:\BonoKat\research project\# study 1\venv\Lib\site-packages\matplotlib\pyplot.py:3358, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3337 @_copy_docstring_and_deprecators(Axes.imshow)
#    3338 def imshow(
#    3339     X: ArrayLike | PIL.Image.Image,
#    (...)
#    3356     **kwargs,
#    3357 ) -> AxesImage:
# -> 3358     __ret = gca().imshow(
#    3359         X,
#    3360         cmap=cmap,
#    3361         norm=norm,
#    3362         aspect=aspect,
#    3363         interpolation=interpolation,
#    3364         alpha=alpha,
#    3365         vmin=vmin,
#    3366         vmax=vmax,
#    3367         origin=origin,
#    3368         extent=extent,
#    3369         interpolation_stage=interpolation_stage,
#    3370         filternorm=filternorm,
#    3371         filterrad=filterrad,
#    3372         resample=resample,
#    3373         url=url,
#    3374         **({"data": data} if data is not None else {}),
#    3375         **kwargs,
#    3376     )
#    3377     sci(__ret)
#    3378     return __ret
#
# File d:\BonoKat\research project\# study 1\venv\Lib\site-packages\matplotlib\__init__.py:1478, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1475 @functools.wraps(func)
#    1476 def inner(ax, *args, data=None, **kwargs):
#    1477     if data is None:
# -> 1478         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1480     bound = new_sig.bind(ax, *args, **kwargs)
#    1481     auto_label = (bound.arguments.get(label_namer)
#    1482                   or bound.kwargs.get(label_namer))
#
# File d:\BonoKat\research project\# study 1\venv\Lib\site-packages\matplotlib\axes\_axes.py:5769, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5765 im.set_url(url)
#    5767 # update ax.dataLim, and, if autoscaling, set viewLim
#    5768 # to tightly fit the image, regardless of dataLim.
# -> 5769 im.set_extent(im.get_extent())
#    5771 self.add_image(im)
#    5772 return im
#
# File d:\BonoKat\research project\# study 1\venv\Lib\site-packages\matplotlib\image.py:985, in AxesImage.set_extent(self, extent, **kwargs)
#     983 self._extent = extent
#     984 corners = (xmin, ymin), (xmax, ymax)
# --> 985 self.axes.update_datalim(corners)
#     986 self.sticky_edges.x[:] = [xmin, xmax]
#     987 self.sticky_edges.y[:] = [ymin, ymax]
#
# File d:\BonoKat\research project\# study 1\venv\Lib\site-packages\matplotlib\axes\_base.py:2512, in _AxesBase.update_datalim(self, xys, updatex, updatey)
#    2510 if not np.any(np.isfinite(xys)):
#    2511     return
# -> 2512 self.dataLim.update_from_data_xy(xys, self.ignore_existing_data_limits,
#    2513                                  updatex=updatex, updatey=updatey)
#    2514 self.ignore_existing_data_limits = False
#
# File d:\BonoKat\research project\# study 1\venv\Lib\site-packages\matplotlib\transforms.py:951, in Bbox.update_from_data_xy(self, xy, ignore, updatex, updatey)
#     948 if len(xy) == 0:
#     949     return
# --> 951 path = Path(xy)
#     952 self.update_from_path(path, ignore=ignore,
#     953                       updatex=updatex, updatey=updatey)
#
# File d:\BonoKat\research project\# study 1\venv\Lib\site-packages\matplotlib\path.py:130, in Path.__init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     101 """
#     102 Create a new path with the given vertices and codes.
#     103
#    (...)
#     127     and codes as read-only arrays.
#     128 """
#     129 vertices = _to_unmasked_float_array(vertices)
# --> 130 _api.check_shape((None, 2), vertices=vertices)
#     132 if codes is not None:
#     133     codes = np.asarray(codes, self.code_type)
#
# File d:\BonoKat\research project\# study 1\venv\Lib\site-packages\matplotlib\_api\__init__.py:161, in check_shape(shape, **kwargs)
#     158 if len(shape) == 1:
#     159     text_shape += ","
# --> 161 raise ValueError(
#     162     f"{k!r} must be {len(shape)}D with shape ({text_shape}), "
#     163     f"but your input has shape {v.shape}"
#     164 )
#
# ValueError: 'vertices' must be 2D with shape (N, 2), but your input has shape (2, 2, 2)

# %%
pac_result.shape
# Out:
# (2, 2, 110)

# %% [markdown]
# _______________

# %% [markdown]
# DIRTY FIELD

# %%
# # Permanently changes the pandas settings
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)
# pd.set_option('display.width', None)

# # All dataframes hereafter reflect these changes.
# display(metadata)

# print('**RESET_OPTIONS**')

# # Resets the options
# pd.reset_option('all')
# display(df)

# %%
planning_idx = np.where(events[0][:, 2] == 11)
planning_events = events[0][planning_idx]
planning_events
# Out:
# array([[ 11373,      0,     11],
#        [ 12581,      0,     11],
#        [ 13773,      0,     11],
#        [ 14898,      0,     11],
#        [ 16040,      0,     11],
#        [ 17223,      0,     11],
#        [ 18414,      0,     11],
#        [ 19656,      0,     11],
#        [ 20831,      0,     11],
#        [ 22123,      0,     11],
#        [ 23673,      0,     11],
#        [ 24848,      0,     11],
#        [ 25956,      0,     11],
#        [ 27065,      0,     11],
#        [ 28206,      0,     11],
#        [ 29398,      0,     11],
#        [ 30598,      0,     11],
#        [ 31715,      0,     11],
#        [ 32915,      0,     11],
#        [ 34056,      0,     11],
#        [ 35382,      0,     11],
#        [ 36565,      0,     11],
#        [ 38114,      0,     11],
#        [ 39348,      0,     11],
#        [ 40615,      0,     11],
#        [ 41814,      0,     11],
#        [ 43048,      0,     11],
#        [ 44231,      0,     11],
#        [ 45431,      0,     11],
#        [ 46689,      0,     11],
#        [ 47890,      0,     11],
#        [ 49198,      0,     11],
#        [ 50406,      0,     11],
#        [ 51648,      0,     11],
#        [ 52856,      0,     11],
#        [ 54040,      0,     11],
#        [ 55265,      0,     11],
#        [ 56506,      0,     11],
#        [ 57698,      0,     11],
#        [ 58898,      0,     11],
#        [ 69031,      0,     11],
#        [ 70223,      0,     11],
#        [ 71773,      0,     11],
#        [ 72956,      0,     11],
#        [ 74165,      0,     11],
#        [ 75356,      0,     11],
#        [ 76548,      0,     11],
#        [ 77723,      0,     11],
#        [ 79032,      0,     11],
#        [ 80240,      0,     11],
#        [ 81490,      0,     11],
#        [ 82673,      0,     11],
#        [ 83923,      0,     11],
#        [ 86506,      0,     11],
#        [ 87681,      0,     11],
#        [ 88831,      0,     11],
#        [ 90031,      0,     11],
#        [ 91223,      0,     11],
#        [ 92423,      0,     11],
#        [ 93640,      0,     11],
#        [ 95048,      0,     11],
#        [ 96206,      0,     11],
#        [ 97439,      0,     11],
#        [ 98640,      0,     11],
#        [ 99865,      0,     11],
#        [101132,      0,     11],
#        [102382,      0,     11],
#        [103598,      0,     11],
#        [104814,      0,     11],
#        [106148,      0,     11],
#        [107340,      0,     11],
#        [108531,      0,     11],
#        [109681,      0,     11],
#        [110831,      0,     11],
#        [112039,      0,     11],
#        [113206,      0,     11],
#        [114314,      0,     11],
#        [115473,      0,     11],
#        [116673,      0,     11],
#        [125898,      0,     11],
#        [127090,      0,     11],
#        [128281,      0,     11],
#        [129473,      0,     11],
#        [130648,      0,     11],
#        [131831,      0,     11],
#        [133040,      0,     11],
#        [134165,      0,     11],
#        [135356,      0,     11],
#        [136556,      0,     11],
#        [137798,      0,     11],
#        [138964,      0,     11],
#        [141339,      0,     11],
#        [142506,      0,     11],
#        [143714,      0,     11],
#        [144915,      0,     11],
#        [146123,      0,     11],
#        [147306,      0,     11],
#        [148506,      0,     11],
#        [149714,      0,     11],
#        [150906,      0,     11],
#        [152089,      0,     11],
#        [153256,      0,     11],
#        [154439,      0,     11],
#        [155606,      0,     11],
#        [156756,      0,     11],
#        [157923,      0,     11],
#        [159056,      0,     11],
#        [160206,      0,     11],
#        [161398,      0,     11],
#        [162564,      0,     11],
#        [163773,      0,     11],
#        [164939,      0,     11],
#        [166140,      0,     11],
#        [167323,      0,     11],
#        [168506,      0,     11],
#        [169698,      0,     11],
#        [170923,      0,     11],
#        [172173,      0,     11]])

# %%
print(epochs_plan.drop_log)

# %%
print(all(proj["active"] for proj in epochs_plan.info["projs"]))
