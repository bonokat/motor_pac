# %% [markdown]
# ## BL SOURCE-LEVEL PAC AND STATS
#
# **This script:**
# 1. Creates theta-gamma PAC comodulograms for condition (all vertices) for each subject and saves PAC data as numpy array
# 2. Runs cluster-besed permutation test on PAC data
#
# **OUTCOME: PAC estimates for all vertices for each subject and statistical assessment of the results**

# %%
import numpy as np
import matplotlib.pyplot as plt
import mne
import os
from utils import check_paths
import pandas as pd
from scipy.io import loadmat
import joblib
import matplotlib.gridspec as gridspec

from pactools import Comodulogram, REFERENCES, raw_to_mask

from mne.channels.layout import find_layout
from functools import partial
from mne.defaults import _handle_default

from mne.viz.topo import _erfimage_imshow_unified, _plot_topo

from mne.viz.utils import (
    _setup_vmin_vmax,
    add_background_image
)
from collections import namedtuple

from mne.stats import permutation_cluster_1samp_test

import scipy
from scipy.stats import zscore

# %matplotlib qt

# %% [markdown]
# 1. PAC analysis per condition per subject

# %%
eeg_data_dir = 'D:\\BonoKat\\research project\\# study 1\\eeg_data\\set'
group = 'Y'
subs = os.listdir(os.path.join(eeg_data_dir, group))
tasks = ['_BL'] # ['_BL', '_MAIN']
task_stages = ['_plan', '_go'] # ['_plan', '_go']

theta_range = np.linspace(4, 8, 20)  # Phase: 4-8 Hz
gamma_range = np.linspace(30, 80, 20)  # Amplitude: 30-80 Hz

tmin = 0.0
tmax = 0.495

# %%
subs[16:]
# Out:
# ['s1_pac_sub63',
#  's1_pac_sub64',
#  's1_pac_sub66',
#  's1_pac_sub67',
#  's1_pac_sub71',
#  's1_pac_sub76',
#  's1_pac_sub77']

# %%
for sub_name in subs[16:]:
    print(f"Processing subject: {sub_name}")
    analysis_dir = os.path.join(eeg_data_dir, group, sub_name, 'preproc', 'analysis')
    pac_save_path = os.path.join(analysis_dir, 'source', 'PAC')
    check_paths(pac_save_path)

    for task in tasks:
        for task_stage in task_stages: # task_stages #############################
            if task == '_BL':
                stcs_path = os.path.join(analysis_dir, 'source', 'morphed_stcs', task, task_stage) 

                stcs = []
                stcs_data = []

                for stc_file in os.listdir(stcs_path):
                    if stc_file.endswith('-rh.stc'): # MNE will load both hemispheres anyway
                        stc_path = os.path.join(stcs_path, stc_file)
                        stc = mne.read_source_estimate(stc_path, subject=sub_name)
                        stc.crop(tmin=tmin, tmax=tmax)
                        stcs.append(stc)
                        stcs_data.append(stc.data)

                source_array = np.stack(stcs_data, axis=0)
                print(source_array.shape)  # (epochs x vertices x time)

                times = stcs[0].times

                #Estimate PAC
                estimator = Comodulogram(
                    fs=stcs[0].sfreq,
                    low_fq_range=theta_range,  # Phase frequencies (theta)
                    high_fq_range=gamma_range, # Amplitude frequencies (gamma)
                    method='tort',
                    progress_bar=True
                    )

                pac_results = np.empty(
                    (len(theta_range), source_array.shape[1], len(gamma_range))
                )

                for i in range(source_array.shape[1]):
                    print(f"Processing source {i+1}/{source_array.shape[1]}")

                    data_flat = np.reshape(source_array[:, i], -1)[None, :]
                    pac = estimator.fit(
                            data_flat,
                            data_flat,
                        )
                    pac_results[:, i] = pac.comod_

                    # if i in range(10):
                    #     # Convert the plot to a Plotly figure (if supported)
                    #     fig = pac.plot(tight_layout=False, cmap='magma')
                    #     # Add a title
                    #     plt.title(f"PAC MI {sub_name[-5:]} - source={i}: {task}{task_stage}")

                    #     # Save the plot
                    #     plt.show()

                np.save(os.path.join(pac_save_path, f"PAC_MI_SOURCE_{sub_name[-5:]}{task}{task_stage}.npy"), pac_results)
        else:
            continue
# Out:
# Processing subject: s1_pac_sub63
# (98, 5124, 249)
# Processing source 1/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 2/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 3/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 4/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5/5124
# [........................................] 100% | 0.25 sec | comodulogram: tort
# Processing source 6/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 7/5124
# [........................................] 100% | 0.25 sec | comodulogram: tort
# Processing source 8/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 9/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 10/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 11/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 12/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 13/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 14/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 15/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 16/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 17/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 18/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 19/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 20/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 21/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 22/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 23/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 24/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 25/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 26/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 27/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 28/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 29/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 30/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 31/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 32/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 33/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 34/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 35/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 36/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 37/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 38/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 39/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 40/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 41/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 42/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 43/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 44/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 45/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 46/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 47/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 48/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 49/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 50/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 51/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 52/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 53/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 54/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 55/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 56/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 57/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 58/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 59/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 60/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 61/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 62/5124
# [........................................] 100% | 0.25 sec | comodulogram: tort
# Processing source 63/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 64/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 65/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 66/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 67/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 68/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 69/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 70/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 71/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 72/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 73/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 74/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 75/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 76/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 77/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 78/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 79/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 80/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 81/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 82/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 83/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 84/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 85/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 86/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 87/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 88/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 89/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 90/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 91/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 92/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 93/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 94/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 95/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 96/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 97/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 98/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 99/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 100/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 101/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 102/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 103/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 104/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 105/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 106/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 107/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 108/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 109/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 110/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 111/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 112/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 113/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 114/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 115/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 116/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 117/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 118/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 119/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 120/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 121/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 122/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 123/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 124/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 125/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 126/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 127/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 128/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 129/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 130/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 131/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 132/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 133/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 134/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 135/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 136/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 137/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 138/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 139/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 140/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 141/5124
# [........................................] 100% | 0.25 sec | comodulogram: tort
# Processing source 142/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 143/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 144/5124
# [........................................] 100% | 0.25 sec | comodulogram: tort
# Processing source 145/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 146/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 147/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 148/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 149/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 150/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 151/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 152/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 153/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 154/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 155/5124
# [........................................] 100% | 0.30 sec | comodulogram: tort
# Processing source 156/5124
# [........................................] 100% | 0.34 sec | comodulogram: tort
# Processing source 157/5124
# [........................................] 100% | 0.30 sec | comodulogram: tort
# Processing source 158/5124
# [........................................] 100% | 0.25 sec | comodulogram: tort
# Processing source 159/5124
# [........................................] 100% | 0.26 sec | comodulogram: tort
# Processing source 160/5124
# [........................................] 100% | 0.27 sec | comodulogram: tort
# Processing source 161/5124
# [........................................] 100% | 0.25 sec | comodulogram: tort
# Processing source 162/5124
# [........................................] 100% | 0.25 sec | comodulogram: tort
# Processing source 163/5124
# [........................................] 100% | 0.25 sec | comodulogram: tort
# Processing source 164/5124
# [........................................] 100% | 0.27 sec | comodulogram: tort
# Processing source 165/5124
# [........................................] 100% | 0.33 sec | comodulogram: tort
# Processing source 166/5124
# [........................................] 100% | 0.31 sec | comodulogram: tort
# Processing source 167/5124
# [........................................] 100% | 0.31 sec | comodulogram: tort
# Processing source 168/5124
# [........................................] 100% | 0.25 sec | comodulogram: tort
# Processing source 169/5124
# [........................................] 100% | 0.25 sec | comodulogram: tort
# Processing source 170/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 171/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 172/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 173/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 174/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 175/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 176/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 177/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 178/5124
# [........................................] 100% | 0.25 sec | comodulogram: tort
# Processing source 179/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 180/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 181/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 182/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 183/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 184/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 185/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 186/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 187/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 188/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 189/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 190/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 191/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 192/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 193/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 194/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 195/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 196/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 197/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 198/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 199/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 200/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 201/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 202/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 203/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 204/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 205/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 206/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 207/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 208/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 209/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 210/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 211/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 212/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 213/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 214/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 215/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 216/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 217/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 218/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 219/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 220/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 221/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 222/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 223/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 224/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 225/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 226/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 227/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 228/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 229/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 230/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 231/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 232/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 233/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 234/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 235/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 236/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 237/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 238/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 239/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 240/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 241/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 242/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 243/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 244/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 245/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 246/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 247/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 248/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 249/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 250/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 251/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 252/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 253/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 254/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 255/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 256/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 257/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 258/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 259/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 260/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 261/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 262/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 263/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 264/5124
# [........................................] 100% | 0.25 sec | comodulogram: tort
# Processing source 265/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 266/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 267/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 268/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 269/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 270/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 271/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 272/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 273/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 274/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 275/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 276/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 277/5124
# [........................................] 100% | 0.25 sec | comodulogram: tort
# Processing source 278/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 279/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 280/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 281/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 282/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 283/5124
# [........................................] 100% | 0.25 sec | comodulogram: tort
# Processing source 284/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 285/5124
# [........................................] 100% | 0.25 sec | comodulogram: tort
# Processing source 286/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 287/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 288/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 289/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 290/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 291/5124
# [........................................] 100% | 0.26 sec | comodulogram: tort
# Processing source 292/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 293/5124
# [........................................] 100% | 0.25 sec | comodulogram: tort
# Processing source 294/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 295/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 296/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 297/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 298/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 299/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 300/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 301/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 302/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 303/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 304/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 305/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 306/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 307/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 308/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 309/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 310/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 311/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 312/5124
# [........................................] 100% | 0.25 sec | comodulogram: tort
# Processing source 313/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 314/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 315/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 316/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 317/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 318/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 319/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 320/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 321/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 322/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 323/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 324/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 325/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 326/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 327/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 328/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 329/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 330/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 331/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 332/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 333/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 334/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 335/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 336/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 337/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 338/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 339/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 340/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 341/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 342/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 343/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 344/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 345/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 346/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 347/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 348/5124
# [........................................] 100% | 0.22 sec | comodulogram: tort
# Processing source 349/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 350/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 351/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 352/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 353/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 354/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 355/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 356/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 357/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 358/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 359/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 360/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 361/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 362/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 363/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 364/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 365/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 366/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 367/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 368/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 369/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 370/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 371/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 372/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 373/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 374/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 375/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 376/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 377/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 378/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 379/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 380/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 381/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 382/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 383/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 384/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 385/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 386/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 387/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 388/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 389/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 390/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 391/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 392/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 393/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 394/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 395/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 396/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 397/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 398/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 399/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 400/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 401/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 402/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 403/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 404/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 405/5124
# [........................................] 100% | 0.22 sec | comodulogram: tort
# Processing source 406/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 407/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 408/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 409/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 410/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 411/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 412/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 413/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 414/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 415/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 416/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 417/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 418/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 419/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 420/5124
# [........................................] 100% | 0.25 sec | comodulogram: tort
# Processing source 421/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 422/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 423/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 424/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 425/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 426/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 427/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 428/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 429/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 430/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 431/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 432/5124
# [........................................] 100% | 0.22 sec | comodulogram: tort
# Processing source 433/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 434/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 435/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 436/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 437/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 438/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 439/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 440/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 441/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 442/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 443/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 444/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 445/5124
# ...
# Processing source 4979/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 4980/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 4981/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 4982/5124
# [........................................] 100% | 0.26 sec | comodulogram: tort
# Processing source 4983/5124
# [........................................] 100% | 0.22 sec | comodulogram: tort
# Processing source 4984/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 4985/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 4986/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 4987/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 4988/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 4989/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 4990/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 4991/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 4992/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 4993/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 4994/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 4995/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 4996/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 4997/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 4998/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 4999/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 5000/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 5001/5124
# [........................................] 100% | 0.22 sec | comodulogram: tort
# Processing source 5002/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 5003/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5004/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5005/5124
# [........................................] 100% | 0.22 sec | comodulogram: tort
# Processing source 5006/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5007/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5008/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5009/5124
# [........................................] 100% | 0.22 sec | comodulogram: tort
# Processing source 5010/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5011/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5012/5124
# [........................................] 100% | 0.22 sec | comodulogram: tort
# Processing source 5013/5124
# [........................................] 100% | 0.22 sec | comodulogram: tort
# Processing source 5014/5124
# [........................................] 100% | 0.22 sec | comodulogram: tort
# Processing source 5015/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5016/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5017/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5018/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5019/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5020/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5021/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5022/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 5023/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5024/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5025/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5026/5124
# [........................................] 100% | 0.22 sec | comodulogram: tort
# Processing source 5027/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 5028/5124
# [........................................] 100% | 0.21 sec | comodulogram: tort
# Processing source 5029/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5030/5124
# [........................................] 100% | 0.22 sec | comodulogram: tort
# Processing source 5031/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 5032/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5033/5124
# [........................................] 100% | 0.25 sec | comodulogram: tort
# Processing source 5034/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5035/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5036/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5037/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5038/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 5039/5124
# [........................................] 100% | 0.22 sec | comodulogram: tort
# Processing source 5040/5124
# [........................................] 100% | 0.22 sec | comodulogram: tort
# Processing source 5041/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5042/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5043/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5044/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5045/5124
# [........................................] 100% | 0.22 sec | comodulogram: tort
# Processing source 5046/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5047/5124
# [........................................] 100% | 0.22 sec | comodulogram: tort
# Processing source 5048/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5049/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 5050/5124
# [........................................] 100% | 0.22 sec | comodulogram: tort
# Processing source 5051/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5052/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5053/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5054/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 5055/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 5056/5124
# [........................................] 100% | 0.22 sec | comodulogram: tort
# Processing source 5057/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5058/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5059/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5060/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5061/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5062/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 5063/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5064/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5065/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 5066/5124
# [........................................] 100% | 0.22 sec | comodulogram: tort
# Processing source 5067/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5068/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5069/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5070/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 5071/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5072/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5073/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5074/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5075/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5076/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5077/5124
# [........................................] 100% | 0.25 sec | comodulogram: tort
# Processing source 5078/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5079/5124
# [........................................] 100% | 0.22 sec | comodulogram: tort
# Processing source 5080/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5081/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 5082/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5083/5124
# [........................................] 100% | 0.22 sec | comodulogram: tort
# Processing source 5084/5124
# [........................................] 100% | 0.22 sec | comodulogram: tort
# Processing source 5085/5124
# [........................................] 100% | 0.22 sec | comodulogram: tort
# Processing source 5086/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5087/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 5088/5124
# [........................................] 100% | 0.22 sec | comodulogram: tort
# Processing source 5089/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5090/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5091/5124
# [........................................] 100% | 0.22 sec | comodulogram: tort
# Processing source 5092/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5093/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5094/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5095/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 5096/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5097/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5098/5124
# [........................................] 100% | 0.22 sec | comodulogram: tort
# Processing source 5099/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5100/5124
# [........................................] 100% | 0.22 sec | comodulogram: tort
# Processing source 5101/5124
# [........................................] 100% | 0.24 sec | comodulogram: tort
# Processing source 5102/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5103/5124
# [........................................] 100% | 0.22 sec | comodulogram: tort
# Processing source 5104/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5105/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5106/5124
# [........................................] 100% | 0.22 sec | comodulogram: tort
# Processing source 5107/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5108/5124
# [........................................] 100% | 0.25 sec | comodulogram: tort
# Processing source 5109/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5110/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5111/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5112/5124
# [........................................] 100% | 0.22 sec | comodulogram: tort
# Processing source 5113/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5114/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5115/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5116/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5117/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5118/5124
# [........................................] 100% | 0.22 sec | comodulogram: tort
# Processing source 5119/5124
# [........................................] 100% | 0.22 sec | comodulogram: tort
# Processing source 5120/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5121/5124
# [........................................] 100% | 0.22 sec | comodulogram: tort
# Processing source 5122/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5123/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing source 5124/5124
# [........................................] 100% | 0.23 sec | comodulogram: tort
# Processing subject: s1_pac_sub64

# %% [markdown]
# _________________

# %%
# Plotting the first 10 vertices of the first epoch
plt.figure(figsize=(10, 6))

for i in range(10):
    plt.plot(times, source_array[0, i], label=f'Vertex {i}')

# %% [markdown]
# ____________

# %% [markdown]
# # STATISTICS
# **Cluster-based permutation test**

# %%
eeg_data_dir = 'D:\\BonoKat\\research project\\# study 1\\eeg_data\\set'

groups = ['Y']
task = '_BL' # ['_BL', '_MAIN']
task_stages = ['_plan', '_go']
block_names = ['_baseline', '_adaptation']

# %% [markdown]
# **STATS FOR DATA AVERAGED ACROSS PHASE AND AMPLITUDE FREQUENCIES**
#
# **PER CONDITION**

# %%
# Main script to process PAC data and run cluster-based permutation tests

############### CREATE ADJACENCY MATRIX FOR STATISTICAL TEST #############
# find_ch_adjacency first attempts to find an existing "neighbor"
# (adjacency) file for given sensor layout.
# If such a file doesn't exist, an adjacency matrix is computed on the fly,
# using Delaunay triangulations.
src_fname = 'D:\\BonoKat\\research project\\# study 1\\mri_data\\fs_output\\freesurfer\\sub_dir\\Y\\fsaverage_bem\\bem\\fsaverage-ico4-src.fif'
src = mne.read_source_spaces(src_fname)
# src.plot(subjects_dir='D:\\BonoKat\\research project\\# study 1\\mri_data\\fs_output\\freesurfer\\sub_dir\\Y')
source_adjacency = mne.spatial_src_adjacency(src)
adj = source_adjacency.tocsr()  # Ensure adjacency is CSR format for fast indexing
print('adjacency shape:', source_adjacency.shape)


############## PROCESS PAC DATA FOR EACH GROUP AND TASK STAGE #############
for group in groups:
    group_save_path = os.path.join(eeg_data_dir, f'{group} group')
    pac_stats_save_path = os.path.join(group_save_path, 'source_pac_stats')
    check_paths(pac_stats_save_path)
    
    # # Create directories for saving figures
    # fig_group_path = os.path.join(pac_stats_save_path, 'figs')
    # fig_group_save_path = os.path.join(fig_group_path, group)
    # fig_task_save_path = os.path.join(fig_group_path, group, task)
    # check_paths(fig_group_path, fig_group_save_path, fig_task_save_path)

    subs = os.listdir(os.path.join(eeg_data_dir, group))

    for task_stage in task_stages: # [task_stages[0]]

        print(f'Processing {group} group, {task} task, {task_stage} stage')

        ############# STACK PAC DATA OF INDIVIDUAL PARTICIPANTS #############

        # Create a list to store the PAC data for each subject
        pac_list = []
        pac_zscore_list = []

        for sub_name in subs:

            sub_dir = os.path.join(eeg_data_dir, group, sub_name)
            pac_dir = os.path.join(sub_dir, 'preproc', 'analysis', 'source', 'PAC')

            # Load PAC data
            pac = np.load(os.path.join(pac_dir, f"PAC_MI_SOURCE_{sub_name[-5:]}{task}{task_stage}.npy"))
            pac_t = np.transpose(pac, (1, 0, 2))

            ### NAN Imputation for PAC Matrices ###
            pac_imputed = pac_t.copy()

            # Step 1: Detect vertices with any NaN in their 20×20 PAC
            nan_mask = np.isnan(pac_t).any(axis=(1, 2))  # shape (5124,)

            if nan_mask.any() == True:
                print(f"Found {nan_mask.sum()} vertices with NaN values.")

                # Step 2: Impute NaNs from neighbors
                for vtx in np.where(nan_mask)[0]:
                    neighbors = adj[[vtx]].indices
                    valid_neighbors = [n for n in neighbors if not nan_mask[n]]
                    # Average PAC matrices from neighbors
                    pac_imputed[vtx] = np.nanmean(pac_t[valid_neighbors], axis=0)

                print(f"NaN imputation for {sub_name} complete.")

            pac_list.append(pac_imputed)
            pac_zscore_list.append(zscore(pac_imputed, axis=0, nan_policy='omit')) # 'omit' ignores NaN values in the z-score calculation

        # Stack them along a new first axis (subject axis)
        pac_all = np.stack(pac_list, axis=0)

        # Z-score the PAC data across subjects
        pac_zscore_all = np.stack(pac_zscore_list, axis=0)
        # pac_zscore_all = zscore(pac_all, axis=1, nan_policy='omit') # another way to zscore the data
        print('PAC array shape:', pac_all.shape) # subs x electrodes x ph_freqs x amp_freqs
        print('z-scored PAC array shape:', pac_zscore_all.shape)

        # Averafe z-scored PAC over phase and amplitude frequencies
        # pac_zscore_all_ave = np.mean(pac_zscore_all, axis=(2, 3)) # (23, 5124) subs x electrodes
        # pac_zscore_all_med = np.median(pac_zscore_all, axis=(2, 3)) # produces more significant clusters

        ### Global normalization
        pac_all_ave = np.mean(pac_all, axis=(2, 3))
        pac_zscore_all_ave = (pac_all_ave - np.nanmean(pac_all_ave)) / np.nanstd(pac_all_ave)
        ###

        # # Save the PAC data
        np.save(os.path.join(pac_stats_save_path, f"PAC_MI_SOURCE_{group}{task}{task_stage}_ZSCORE_freqs_ave.npy"), pac_zscore_all_ave)

        # # ############# PLOT AND SAVE Z-SCORED PAC AVERAGED ACROSS PARTICIPANTS #############
        # pac_plot, ax1 = plot_rect_topo_from_epochs(np.mean(pac_zscore_all_ave, axis=(0)), epochs.info,
        #                                         title=f'{group}{task}{task_stage}{block_name}: Averaged z-scored PAC MI',
        #                                         cmap='PiYG', vmin=-0.5, vmax=0.5)
        # plt.savefig(os.path.join(fig_task_save_path, f"pac_mi_{group}{task}{task_stage}{block_name}_PAC_MI_AVE_TOPO.png"), dpi=300)

        # pac_ave_plot, ax2 = plot_matrix_topo_from_epochs(np.mean(pac_zscore_all, axis=(0)), epochs.info,
        #                                                 title=f'{group}{task}{task_stage}{block_name}: z-scored PAC MI',
        #                                                 cmap='PiYG', vmin=-0.5, vmax=0.5)
        # plt.savefig(os.path.join(fig_task_save_path, f"pac_mi_{group}{task}{task_stage}{block_name}_PAC_MI_TOPO.png"), dpi=300)


        ############# RUN CLUSTER-BASED PERMUTATION TEST #############

        tail = 0 # two-tailed test

        # Set the threshold for including data bins in clusters with t-value corresponding to p=0.01
        # Because we conduct a two-tailed test, we divide the p-value by 2 (which means we're making use of both tails of the distribution).
        # As the degrees of freedom, we specify the number of observations (here: subjects) minus 1.
        # Finally, we subtract 0.01 / 2 from 1, to get the critical t-value on the right tail
        p_threshold = 0.01
        degrees_of_freedom = pac_all.shape[0] - 1
        t_thresh = scipy.stats.t.ppf(1 - p_threshold / 2, df=degrees_of_freedom)

        #!
        # threshold_tfce = dict(start=0, step=0.2) # Threshold-free cluster enhancement (TFCE) - more conservative, similar results

        # Set the number of permutations
        n_permutations = 10000

        # Run the analysis
        T_obs, clusters, cluster_p_values, H0 = permutation_cluster_1samp_test(
            pac_zscore_all_ave,
            n_permutations=n_permutations,
            threshold=t_thresh, # None - default threshold based on t-distribution
            tail=tail,
            adjacency=adj,
            step_down_p=0.05,  # step-down p-value correction instead of max stats
            out_type="mask",
            max_step=1,
            n_jobs=-1 # to use all available CPU cores
        )

        # # Save the results
        np.save(os.path.join(pac_stats_save_path, f"PAC_MI_SOURCE_{group}{task}{task_stage}_freqs_ave_T_obs.npy"), T_obs)
        np.save(os.path.join(pac_stats_save_path, f"PAC_MI_SOURCE_{group}{task}{task_stage}_freqs_ave_clusters.npy"), np.array(clusters, dtype=object))
        np.save(os.path.join(pac_stats_save_path, f"PAC_MI_SOURCE_{group}{task}{task_stage}_freqs_ave_cluster_p_values.npy"), cluster_p_values)
        np.save(os.path.join(pac_stats_save_path, f"PAC_MI_SOURCE_{group}{task}{task_stage}_freqs_ave_H0.npy"), H0)

        # SANITY CHECKS
        print(f't_thresh = {t_thresh}')
        print(f'T_obs_mean = {T_obs.mean()}')
        print(f'cluster_p_values = {cluster_p_values}')

        alpha = 0.05  # significance threshold
        significant_clusters = [i for i, p in enumerate(cluster_p_values) if p < alpha]
        print(f"Condition {task_stage}: Found {len(significant_clusters)} significant clusters out of {len(cluster_p_values)} total clusters.")


        # ####### PLOT THE RESULTS #######
        # plot_significant_topomap(T_obs, clusters, cluster_p_values, epochs.info, group=group, task=task, task_stage=task_stage, block_name=block_name)
        # plt.savefig(os.path.join(fig_task_save_path, f"pac_cluster_stats_{group}{task}{task_stage}_freq_ave_TOPO.png"), dpi=300)
# Out:
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     [done]
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     [done]
#     2 source spaces read
# -- number of adjacent vertices : 5124
# adjacency shape: (5124, 5124)
# Processing Y group, _BL task, _plan stage
# Found 5 vertices with NaN values.
# NaN imputation for s1_pac_sub01 complete.
# Found 3 vertices with NaN values.
# NaN imputation for s1_pac_sub07 complete.
# Found 3 vertices with NaN values.
# NaN imputation for s1_pac_sub10 complete.
# Found 13 vertices with NaN values.
# NaN imputation for s1_pac_sub11 complete.
# Found 9 vertices with NaN values.
# NaN imputation for s1_pac_sub22 complete.
# Found 17 vertices with NaN values.
# NaN imputation for s1_pac_sub24 complete.
# Found 15 vertices with NaN values.
# NaN imputation for s1_pac_sub26 complete.
# Found 17 vertices with NaN values.
# NaN imputation for s1_pac_sub29 complete.
# Found 9 vertices with NaN values.
# NaN imputation for s1_pac_sub32 complete.
# Found 8 vertices with NaN values.
# NaN imputation for s1_pac_sub33 complete.
# Found 2 vertices with NaN values.
# NaN imputation for s1_pac_sub38 complete.
# Found 13 vertices with NaN values.
# NaN imputation for s1_pac_sub43 complete.
# Found 1 vertices with NaN values.
# NaN imputation for s1_pac_sub52 complete.
# Found 6 vertices with NaN values.
# NaN imputation for s1_pac_sub58 complete.
# Found 3 vertices with NaN values.
# NaN imputation for s1_pac_sub59 complete.
# Found 26 vertices with NaN values.
# NaN imputation for s1_pac_sub61 complete.
# Found 5 vertices with NaN values.
# NaN imputation for s1_pac_sub63 complete.
# Found 12 vertices with NaN values.
# NaN imputation for s1_pac_sub64 complete.
# Found 8 vertices with NaN values.
# NaN imputation for s1_pac_sub66 complete.
# Found 13 vertices with NaN values.
# NaN imputation for s1_pac_sub67 complete.
# Found 7 vertices with NaN values.
# NaN imputation for s1_pac_sub71 complete.
# Found 10 vertices with NaN values.
# NaN imputation for s1_pac_sub76 complete.
# Found 8 vertices with NaN values.
# NaN imputation for s1_pac_sub77 complete.
# PAC array shape: (23, 5124, 20, 20)
# z-scored PAC array shape: (23, 5124, 20, 20)
# stat_fun(H1): min=-6.152869728046657 max=3.664602853969475
# Running initial clustering …
# Found 57 clusters
#   0%|          | Permuting : 0/9999 [00:00<?,       ?it/s]
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
#   0%|          | Permuting : 0/9999 [00:00<?,       ?it/s]
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# t_thresh = 2.818756060596369
# T_obs_mean = -0.13270681161022274
# cluster_p_values = [0.8343 0.5975 0.9991 0.9955 0.9957 0.9937 0.9849 0.9983 0.9993 0.6229
#  0.9637 0.6387 0.0258 0.9993 0.9468 0.1773 0.9981 0.9437 0.8722 0.9488
#  0.9827 0.443  0.7675 0.9989 0.9991 0.9991 0.9976 0.9811 0.997  0.9994
#  0.8617 0.6057 0.9981 0.9943 0.7198 0.1992 0.5123 0.9987 0.9824 0.8119
#  0.9994 0.9991 0.8713 0.9994 0.7255 0.9683 0.9982 0.4899 0.8325 0.8694
#  0.9669 0.9938 0.9993 0.8911 0.8754 0.9835 0.9981]
# Condition _plan: Found 1 significant clusters out of 57 total clusters.
# Processing Y group, _BL task, _go stage
# Found 5 vertices with NaN values.
# NaN imputation for s1_pac_sub01 complete.
# Found 3 vertices with NaN values.
# NaN imputation for s1_pac_sub07 complete.
# Found 3 vertices with NaN values.
# NaN imputation for s1_pac_sub10 complete.
# Found 13 vertices with NaN values.
# NaN imputation for s1_pac_sub11 complete.
# Found 9 vertices with NaN values.
# NaN imputation for s1_pac_sub22 complete.
# Found 17 vertices with NaN values.
# NaN imputation for s1_pac_sub24 complete.
# Found 15 vertices with NaN values.
# NaN imputation for s1_pac_sub26 complete.
# Found 17 vertices with NaN values.
# NaN imputation for s1_pac_sub29 complete.
# Found 9 vertices with NaN values.
# NaN imputation for s1_pac_sub32 complete.
# Found 8 vertices with NaN values.
# NaN imputation for s1_pac_sub33 complete.
# Found 2 vertices with NaN values.
# NaN imputation for s1_pac_sub38 complete.
# Found 13 vertices with NaN values.
# NaN imputation for s1_pac_sub43 complete.
# Found 1 vertices with NaN values.
# NaN imputation for s1_pac_sub52 complete.
# Found 6 vertices with NaN values.
# NaN imputation for s1_pac_sub58 complete.
# Found 3 vertices with NaN values.
# NaN imputation for s1_pac_sub59 complete.
# Found 26 vertices with NaN values.
# NaN imputation for s1_pac_sub61 complete.
# Found 5 vertices with NaN values.
# NaN imputation for s1_pac_sub63 complete.
# Found 12 vertices with NaN values.
# NaN imputation for s1_pac_sub64 complete.
# Found 8 vertices with NaN values.
# NaN imputation for s1_pac_sub66 complete.
# Found 13 vertices with NaN values.
# NaN imputation for s1_pac_sub67 complete.
# Found 7 vertices with NaN values.
# NaN imputation for s1_pac_sub71 complete.
# Found 10 vertices with NaN values.
# NaN imputation for s1_pac_sub76 complete.
# Found 8 vertices with NaN values.
# NaN imputation for s1_pac_sub77 complete.
# PAC array shape: (23, 5124, 20, 20)
# z-scored PAC array shape: (23, 5124, 20, 20)
# stat_fun(H1): min=-4.851339182718787 max=2.2689386926072963
# Running initial clustering …
# Found 40 clusters
#   0%|          | Permuting : 0/9999 [00:00<?,       ?it/s]
# Step-down-in-jumps iteration #1 found 0 clusters to exclude from subsequent iterations
# t_thresh = 2.818756060596369
# T_obs_mean = -0.2694719219444982
# cluster_p_values = [0.6116 0.6915 0.9944 0.6275 0.8469 0.99   0.6611 0.9962 0.8289 0.9413
#  0.996  0.9943 0.1385 0.9342 0.6507 0.4575 0.9929 0.6113 0.624  0.9924
#  0.7682 0.8216 0.1162 0.5946 0.8547 0.7218 0.9408 0.3775 0.0823 0.996
#  0.6418 0.6892 0.3351 0.991  0.9884 0.6294 0.8277 0.9886 0.9963 0.8303]
# Condition _go: Found 0 significant clusters out of 40 total clusters.

# %% [markdown]
# ______________________________

# %% [markdown]
# Dirty field

# %% [markdown]
# PLOTTING PAC DISTRIBUTIONS

# %%
# Global distribution of all PAC values across all subjects and vertices
# Flatten all PAC values into a 1D array
all_pac_values = pac_all.flatten()

# Remove NaNs if present
all_pac_values = all_pac_values[~np.isnan(all_pac_values)]

# Plot histogram
plt.figure(figsize=(8, 5))
plt.hist(all_pac_values, bins=100, color='skyblue', edgecolor='k')
plt.title("Distribution of all PAC z-scores")
plt.xlabel("PAC z-score")
plt.ylabel("Count")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Distribution per subject (e.g., mean PAC per subject)
# Mean PAC per subject, averaged over all space and frequencies
subject_means = np.nanmean(pac_all, axis=(1, 2, 3))  # shape (23,)

plt.figure(figsize=(8, 5))
plt.hist(subject_means, bins=15, color='coral', edgecolor='k')
plt.title("Mean PAC z-scores per subject")
plt.xlabel("Mean PAC z-score")
plt.ylabel("Count")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Violin plot: per-subject PAC distributions
import seaborn as sns

# Sample 5000 random PAC values per subject (if needed for speed)
np.random.seed(42)
subset = [pac_all[i].flatten() for i in range(23)]
subset = [x[~np.isnan(x)] for x in subset]
subset = [np.random.choice(x, 5000, replace=False) if len(x) > 5000 else x for x in subset]

# Create DataFrame for seaborn
import pandas as pd
df = pd.DataFrame({
    'PAC': np.concatenate(subset),
    'Subject': np.concatenate([[f'Subj {i+1}'] * len(x) for i, x in enumerate(subset)])
})

plt.figure(figsize=(12, 6))
sns.violinplot(data=df, x='Subject', y='PAC', inner='box')
plt.title("PAC value distribution per subject")
plt.ylabel("PAC z-score")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
np.min(pac_all)
# Out:
# np.float64(5.687941503192036e-07)
